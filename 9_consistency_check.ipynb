# %%
import pandas as pd
import numpy as np
import os
from datetime import date
import time
import json
today = date.today()
path = os.getcwd()
print(f'💚 Today is {today}')
# Out:
# 💚 Today is 2025-06-11

# %% [markdown]
# # Trying the network graphs with rearranged categories

# %%
## Rearranging the methods and data types
re_methods = {"Multigenerational Measures": "Others_Measure",
              "Non‐parametric Approaches": "Others_Measure",
              "Others": "Others_Measure",}

re_dttype = {"Opportunity Atlas": "Linked Administrative Data",
             "International Panel Data": "Panel/Longitudinal Surveys",
             "University/Institution Data": "Others_DataType",
             "Pseudo-Panel/Household Budget Survey": "National Survey Data",
             "Archival/Historical Data": "Administrative/Registry Data",
             "Big Data": "Others_DataType",
             "Others": "Others_DataType"}

re_rqtype = {"Others": "Others_RqType"}
# *------For Research Question Types, it was too difficult to rearrange.

# %%
from neo4j import GraphDatabase
import pandas as pd

driver = GraphDatabase.driver("bolt://localhost:7687", auth=("neo4j", "your_password"))

data_type_query = """
MATCH (d:DataType)
WHERE d.name IS NOT NULL
SET d.rearranged = 
  CASE d.name
    WHEN "Opportunity Atlas" THEN "Linked Administrative Data"
    WHEN "International Panel Data" THEN "Panel/Longitudinal Surveys"
    WHEN "University/Institution Data" THEN "Others_DataType"
    WHEN "Pseudo-Panel/Household Budget Survey" THEN "National Survey Data"
    WHEN "Archival/Historical Data" THEN "Administrative/Registry Data"
    WHEN "Big Data" THEN "Others_DataType"
    ELSE d.name
  END
"""

measure_query = """
MATCH (m:Measure)
WHERE m.name IS NOT NULL
SET m.rearranged = 
  CASE m.name
    WHEN "Multigenerational Measures" THEN "Others_Measure"
    WHEN "Non‐parametric Approaches" THEN "Others_Measure"
    ELSE m.name
  END
"""

# rq_type_query = """
# MATCH (r:RqType)
# WHERE r.name IS NOT NULL
# SET r.rearranged =
#     CASE r.name
#         WHEN "Others" THEN "Others_RqType"
#         ELSE r.name
#     END;
# """

with driver.session() as session:
    session.run(data_type_query)
    session.run(measure_query)
    # session.run(rq_type_query)

driver.close()

# %% [markdown]
# # Graph Viz

# %%
# Graph Data:
df_feature_edges = pd.read_csv(f'{path}/results/weights_properties_citations_noTypeYear.csv')
# df_feature_edges = pd.read_csv(f'{path}/results/weights_properties_citations_noTypeYear_rearranged-values.csv')
# With the new values with the titles in the prompt:
# df_feature_edges = pd.read_csv(f'{path}/results/weights_properties_citations_noTypeYear_titled-values.csv')

# %%
def scale_weight(w, min_w, max_w, min_thick=1, max_thick=8):
    if max_w == min_w:
        return (min_thick + max_thick) / 2
    return min_thick + (w - min_w) / (max_w - min_w) * (max_thick - min_thick)



color_labels = {
                # Measure Categories
                "Regression‐based Measures" : "#B5DBA5",
                "Rank‐based Measures": "#B5DBA5",
                "Transition Matrix / Probability Measures": "#B5DBA5",
                "Absolute Mobility Measures": "#B5DBA5",
                "Multigenerational Measures": "#B5DBA5",
                "Decomposition / Structural Approaches": "#B5DBA5",
                "Non‐parametric Approaches": "#B5DBA5",
                "Others_Measure": "#B5DBA5",
                
                # Data Categories
                "Panel/Longitudinal Surveys": "#339999",
                "Administrative/Registry Data": "#339999",
                "National Survey Data": "#339999",
                "Opportunity Atlas": "#339999",
                "Natural/Experimental Data": "#339999",
                "Linked Administrative Data": "#339999",
                "International Panel Data": "#339999",
                "Rich List Data": "#339999",
                "University/Institution Data": "#339999",
                "Pseudo-Panel/Household Budget Survey": "#339999",
                "Archival/Historical Data": "#339999",
                "Big Data": "#339999",
                "No dataset": "#339999",
                "Others_DataType": "#339999",
                
                # RQ Categories
                "Measurement and Methodological Advances": "#F4A988",
                "Empirical Estimates and Determinants": "#F4A988",
                "Policy, Institutional, and Geographic Impacts": "#F4A988",
                "Intergenerational Wealth Mobility and Inheritance": "#F4A988",
                "Demographic Differences in Mobility (Race, Gender, etc.)" : "#F4A988",
                "Mobility and Non-Income Outcomes (Health, Wellbeing, etc.)": "#F4A988",
                "Theoretical and Structural Models": "#F4A988",
                "Perceptions of Mobility and Attitudes": "#F4A988",
                "Others_RqType": "#F4A988"}

# %%
import plotly.graph_objects as go
import networkx as nx
import math

# Build the graph
G = nx.DiGraph()
for _, row in df_feature_edges.iterrows():
    G.add_edge(row['from_val'], row['to_val'], weight=row['weight'])

# Layout
pos = nx.spring_layout(G, seed=42, k=5 / math.sqrt(G.order()))

# --- CENTRALITY METRICS ---
betweenness = nx.betweenness_centrality(G)
degree = dict(G.degree())

# How many top central nodes to show
top_k = 7 # total = 22

# Top-k nodes by betweenness centrality
top_betweenness_nodes = sorted(betweenness, key=betweenness.get, reverse=True)[:top_k]
# Top-k nodes by degree centrality
top_degree_nodes = sorted(degree, key=degree.get, reverse=True)[:top_k]

# --- GEOMETRIC CENTER ZONE ---
center_radius = 0.115
geometric_center_nodes = [node for node, (x, y) in pos.items() if abs(x) <= center_radius and abs(y) <= center_radius]

# --- CREATE SUBGRAPH FUNCTION ---
def make_subgraph_plot(subgraph_nodes_ordered, centrality_dict, title):
    G_sub = G.subgraph(subgraph_nodes_ordered).copy()
    pos_sub = {n: pos[n] for n in G_sub.nodes()}
    
    edge_weights = [G_sub[u][v]['weight'] for u, v in G_sub.edges()]
    min_w, max_w = min(edge_weights, default=1), max(edge_weights, default=1)
    scaled_widths = [scale_weight(w, min_w, max_w) for w in edge_weights]
    
    # Edge traces
    edge_traces = []
    for (u, v), width in zip(G_sub.edges(), scaled_widths):
        edge_traces.append(go.Scatter(
            x=[pos_sub[u][0], pos_sub[v][0], None],
            y=[pos_sub[u][1], pos_sub[v][1], None],
            mode='lines',
            line=dict(width=width, color='gray'),
            showlegend=False,
        ))

    # Node traces with correct rank labels
    node_traces = []
    for i, node in enumerate(subgraph_nodes_ordered):
        x, y = pos_sub[node]
        rank_label = str(i + 1)  # ranked order (1 = highest centrality, or closest to center)
        node_traces.append(go.Scatter(
            x=[x],
            y=[y],
            mode='markers+text',
            text=[rank_label],
            textposition='middle center',
            textfont=dict(size=24, color='white'),
            marker=dict(
                size=30,
                color=color_labels.get(node, '#cccccc'),
                line=dict(width=2, color=color_labels.get(node, '#cccccc')),            ),
            hoverinfo='text',
            name=node,
            showlegend=True
        ))

    return go.Figure(data=edge_traces + node_traces, layout=go.Layout(
        title=title,
        showlegend=True,
        hovermode='closest',
        plot_bgcolor='rgba(255,255,255,0)',
        margin=dict(b=20, l=5, r=5, t=40),
        font=dict(size=16, color='black'),
        # font_family="Times New Roman",
        font_family = "Avenir",
        xaxis=dict(showgrid=False, zeroline=False),
        yaxis=dict(showgrid=False, zeroline=False)
    ))



# --- DISPLAY THREE PLOTS ---
# Sort geometric center nodes by distance to origin
geom_sorted = sorted(geometric_center_nodes, key=lambda n: pos[n][0]**2 + pos[n][1]**2)

fig_geom = make_subgraph_plot(geom_sorted, {}, 'Geometric Center Nodes')
fig_betw = make_subgraph_plot(top_betweenness_nodes, betweenness, 'Top Betweenness Centrality Nodes')
fig_deg = make_subgraph_plot(top_degree_nodes, degree, 'Top Degree Centrality Nodes')

fig_geom.show()
fig_betw.show()
fig_deg.show()

# %%
timestamp = time.strftime("%Y-%m-%d_%H%M%S")
fig_geom.write_image(f'{path}/results/Paper/img/feature_geom_center_graph_{timestamp}.svg')
fig_betw.write_image(f'{path}/results/Paper/img/feature_top_betweenness_graph_{timestamp}.svg')
fig_deg.write_image(f'{path}/results/Paper/img/feature_top_degree_graph_{timestamp}.svg')

# %%
# Build the graph
G = nx.DiGraph()
for _, row in df_feature_edges.iterrows():
    G.add_edge(row['from_val'], row['to_val'], weight=row['weight'])

# Layout
pos = nx.spring_layout(G, seed=42, k=5 / math.sqrt(G.order()))

# Edge thickness based on weight
edge_weights = [G[u][v]['weight'] for u, v in G.edges()]
min_w, max_w = min(edge_weights), max(edge_weights)

scaled_widths = [scale_weight(w, min_w, max_w) for w in edge_weights]


edge_traces = []
for (u, v), width in zip(G.edges(), scaled_widths):
    edge_traces.append(go.Scatter(
        x=[pos[u][0], pos[v][0], None],
        y=[pos[u][1], pos[v][1], None],
        mode='lines',
        line=dict(width=width, color='gray'),
        showlegend=False,
        name=f'{u} → {v}',
        hoverinfo='text',
        text=[f'{u} → {v}<br>Weight: {G[u][v]["weight"]}']
    ))

# Map node labels to color
node_labels = list(G.nodes())
x_pos = [pos[node][0] for node in node_labels]
y_pos = [pos[node][1] for node in node_labels]


# Create individual node traces with legends
node_traces = []
for i, label in enumerate(node_labels):
    node_traces.append(go.Scatter(
        x=[x_pos[i]],
        y=[y_pos[i]],
        mode='markers',
        name=label,
        marker=dict(
            size=30,
            color=color_labels[label],
            line=dict(width=2, color=color_labels[label])
        ),
        hoverinfo='text',
        text=[label],
        showlegend=True
    ))

# Final plot
fig = go.Figure(data=edge_traces + node_traces, layout=go.Layout(
    showlegend=False,
    hovermode='closest',
    # paper_bgcolor='rgba(0, 0, 0, 0)',
    plot_bgcolor='rgba(0, 0, 0, 0)',
    margin=dict(b=20, l=5, r=5, t=40),
    font=dict(size=16, color='black'),
    font_family="Times New Roman",
    xaxis=dict(showgrid=False, zeroline=False),
    yaxis=dict(showgrid=False, zeroline=False)
))

fig.show()

# %%
# fig.write_image(f'{path}/results/Paper/img/feature_citation_graph_{timestamp}.svg')

# %%
citations_617 = pd.read_csv(f'{path}/results/citations_count_617only_with_ranks.csv')
citations_617['re_category_1'] = citations_617['category_1'].replace(re_methods)
citations_617['re_category_2'] = citations_617['category_2'].replace(re_methods)
citations_617['re_data_cat'] = citations_617['data_cat'].replace(re_dttype)
citations_617['re_rq_cat'] = citations_617['rq_cat'].replace(re_rqtype)

# %%
citations_617.head()
# Out:
#                                  id  citations_count  \
# 0  https://openalex.org/W2105584013              169
# 1  https://openalex.org/W2022256544              150
# 2  https://openalex.org/W2122216841              131
# 3  https://openalex.org/W2091916425              112
# 4  https://openalex.org/W3093752946               98
#
#                                                title  \
# 0  Where is the land of Opportunity? The Geograph...
# 1  An Equilibrium Theory of the Distribution of I...
# 2  Income Inequality, Equality of Opportunity, an...
# 3  Fortunate Sons: New Estimates of Intergenerati...
# 4        Trends in Intergenerational Income Mobility
#
#                        data_cat                                rq_cat  \
# 0    Linked Administrative Data  Empirical Estimates and Determinants
# 1                    No dataset     Theoretical and Structural Models
# 2      International Panel Data  Empirical Estimates and Determinants
# 3  Administrative/Registry Data  Empirical Estimates and Determinants
# 4    Panel/Longitudinal Surveys  Empirical Estimates and Determinants
#
#                               category_1  \
# 0                    Rank‐based Measures
# 1  Decomposition / Structural Approaches
# 2              Regression‐based Measures
# 3              Regression‐based Measures
# 4              Regression‐based Measures
#
#                                  category_2  citation_rank  cited_by_count  \
# 0  Transition Matrix / Probability Measures            1.0          2341.0
# 1     Decomposition / Structural Approaches            2.0          2152.0
# 2                                       NaN            3.0          1529.0
# 3                                       NaN            6.0           654.0
# 4                 Regression‐based Measures           12.0           445.0
#
#    citation_rank_617                          re_category_1  \
# 0                1.0                    Rank‐based Measures
# 1                2.0  Decomposition / Structural Approaches
# 2                3.0              Regression‐based Measures
# 3                4.0              Regression‐based Measures
# 4                5.0              Regression‐based Measures
#
#                               re_category_2                   re_data_cat  \
# 0  Transition Matrix / Probability Measures    Linked Administrative Data
# 1     Decomposition / Structural Approaches                    No dataset
# 2                                       NaN    Panel/Longitudinal Surveys
# 3                                       NaN  Administrative/Registry Data
# 4                 Regression‐based Measures    Panel/Longitudinal Surveys
#
#                               re_rq_cat
# 0  Empirical Estimates and Determinants
# 1     Theoretical and Structural Models
# 2  Empirical Estimates and Determinants
# 3  Empirical Estimates and Determinants
# 4  Empirical Estimates and Determinants

# %%
import plotly.graph_objects as go
import pandas as pd

# Define the variables you want dropdown control for
variables = ['re_category_1', 're_category_2', 're_data_cat', 're_rq_cat']

# Bin citation rank
citations_617['percentile_bin'] = pd.qcut(
    citations_617['citation_rank_617'],
    q=10,
    labels=[f"P{i*10}-{(i+1)*10}" for i in range(10)],
    duplicates='drop'
)

# Create color scale
custom_colorscale = [
    [0.0, 'lightgray'],
    [0.000001, 'rgb(68,1,84)'],
    [1.0, 'rgb(253,231,37)']
]

# Store all heatmap traces
traces = []
buttons = []

for i, variable in enumerate(variables):
    pivot_table = (
        citations_617
        .groupby([variable, 'percentile_bin'], observed=True)['citations_count']
        .sum()
        .unstack(fill_value=0)
    )
    pivot_table = pivot_table / pivot_table.values.sum()

    trace = go.Heatmap(
        z=pivot_table.values,
        x=pivot_table.columns.astype(str),
        y=pivot_table.index,
        colorscale=custom_colorscale,
        zmin=0.00001,
        zmax=0.05,  # or pivot_table.values.max() if you want adaptive range
        xgap=2,
        ygap=2,
        visible=(i == 0),  # Only first is visible initially
        colorbar=dict(title="Normalized Citations")
    )
    traces.append(trace)

    # Add dropdown button
    button = dict(
        label=variable,
        method='update',
        args=[
            {'visible': [j == i for j in range(len(variables))]},
            {'title': f'Total Citations by {variable} and Citation Rank Percentile',
             'yaxis': {'title': variable}}
        ]
    )
    buttons.append(button)

# Create the figure with all traces and the dropdown
fig = go.Figure(data=traces)

fig.update_layout(
    updatemenus=[
        dict(
            type='dropdown',
            showactive=True,
            buttons=buttons,
            x=1.05,
            xanchor='left',
            y=1.1,
            yanchor='top'
        )
    ],
    title=f"Total Citations by {variables[0]} and Citation Rank Percentile",
    xaxis_title="Citation Rank Percentile",
    yaxis_title=variables[0]
)

fig.show()

# %% [markdown]
# # GPT: Reassigning the categories (Consistency Check)

# %%
from openai import OpenAI
from dotenv import load_dotenv
# OpenAI
load_dotenv() 
openai_API_KEY = os.getenv("OPENAI_API_KEY")
openai_client = OpenAI(api_key=openai_API_KEY)
gpt_model = "o3-mini" #o3-mini-2025-01-31

# %%
import re

def clean_abs(abs_text):
    abs_text = re.sub(r'[^\x00-\x7F]+', '', abs_text)  # Remove non-ASCII characters (like Korean)
    abs_text = re.sub(r'\bp\.\s*\d+\b', '', abs_text)  # Remove page numbers
    abs_text = re.sub(r'[A-Z][a-z]+(?:\s+(?:and|&)\s+[A-Z][a-z]+)*(?:,\s+[A-Z][a-z]+)*\s*\(\d{4}\)', '', abs_text)  # Remove parenthesis citation
    abs_text = re.sub(r'[A-Z][a-z]+(?:\s+(?:and|&)\s+[A-Z][a-z]+)*(?:,\s+[A-Z][a-z]+)*(?:,\s*\d{4})', '', abs_text)  # Remove text citation
    
    abs_text = re.sub(r'<[^>]+>', '', abs_text)  # Remove HTML tags
    abs_text = re.sub(r'\b(?:ABSTRACT|Abstract)\b', '', abs_text) # Remove the term 'ABSTRACT' or 'Abstract' (case-sensitive, preserving other variations)
    abs_text = re.sub(r'https?://\S+', '', abs_text)
    abs_text = re.sub(r'www\.\S+', '', abs_text)
    abs_text = re.sub(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,7}\b', '', abs_text)
    abs_text = re.sub('intergenerational elasticity', 'IGE', abs_text, flags=re.IGNORECASE)
    # Normalize white spaces
    abs_text = re.sub(r'(?<!\w)[.,]+(?!\w)', '', abs_text)  # Remove isolated periods and commas
    abs_text = re.sub(r'\s+', ' ', abs_text).strip()
    return abs_text

# %%
from pydantic import BaseModel

class GetCat(BaseModel):
    category: int
    data_type: str

# %%
df = pd.read_csv(f'{path}/data_abstracts/true_mobility_studies_617_forKGs_cleaned.csv')
df.shape
# Out:
# (617, 56)

# %%
def estimate_cost(prompt_toks, completion_toks, model="o3-mini"):
    pricing = {
        "o3-mini":{"prompt": 0.0011, "completion": 0.0044},  # pricing per 1K tokens
    }
    rate = pricing[model]
    return (prompt_toks / 1000) * rate["prompt"] + (completion_toks / 1000) * rate["completion"]

# %% [markdown]
# ## Methods

# %%
import logging

cat = {}
estimated_costs = {}

for i, row in df.iterrows():
# for i, row in df[~df.index.isin(cat.keys())].iterrows():  # Only process rows without those already in 'cat'
    abs = row['abs'].strip()
    abs_clean = clean_abs(abs)
    print(f'Processing {row.id}')
    start_time = time.time()
    completion = openai_client.beta.chat.completions.parse(
                model= gpt_model,
                messages=[
                    { 
                    "role": "assistant",
                    "content": "You are a research assistant in the Social Sciences domain. I, the researcher, have an abstract of a paper that studied inter/multi generational wealth/income/earning mobility. I want you to categorize the measure(s) that the paper used based on the abstract."
                    
                    },
                    {
                        "role": "user", 
                        "content":f"""
                                ```Title: {row['title']}
                                                        
                                ```Abstracts
                                {abs_clean}
                                ```
                                First, recognize what measure(s) the papers used based on the abstracts. Here, 'measures' mean an estimate from a model or an equation that quantifies the inter/multi generational wealth/income/earning mobility.
                                Does it belong to any of the following categories?
                                1. Regression‐based Measures 
                                2. Rank‐based Measures
                                3. Transition Matrix / Probability Measures
                                4. Absolute Mobility Measures
                                5. Multigenerational Measures
                                6. Decomposition / Structural Approaches
                                7. Non‐parametric Approaches
                                8. Others
                                
                                Return the category that the measure(s) belong to as a number, and the exact name of the measure(s) if possible. For example, if it belongs to '1', return also the name of the measure(s) such as 'Intergenerational Elasticity (IGE)'. 
                                Don't repeat the name of category here like 'Regression‐based Measures - IGE'.
                                If the measure(s) do not belong to any category, return '8' and the exact name of the measure.
                                """
                    }
                ],
                response_format=GetCat,
            )
    results = completion.choices[0].message.content
    tokens_prompt = completion.usage.prompt_tokens
    tokens_completion = completion.usage.completion_tokens
    cost = estimate_cost(tokens_prompt, tokens_completion, model=gpt_model)
    estimated_costs[i] = cost
    cat[i] = results   
        
logging.info('✅ Done! The process time is:', time.time()-start_time)
# Out:
# Processing https://openalex.org/W3176622639
# Processing https://openalex.org/W3176921257
# Processing https://openalex.org/W3178385122
# Processing https://openalex.org/W3181553951
# Processing https://openalex.org/W3181973673
# Processing https://openalex.org/W3182550406
# Processing https://openalex.org/W3184422859
# Processing https://openalex.org/W3185155858
# Processing https://openalex.org/W3186457560
# Processing https://openalex.org/W3189747191
# Processing https://openalex.org/W3190097825
# Processing https://openalex.org/W3190102834
# Processing https://openalex.org/W3192903419
# Processing https://openalex.org/W3195123941
# Processing https://openalex.org/W3197901707
# Processing https://openalex.org/W3198616739
# Processing https://openalex.org/W3202153609
# Processing https://openalex.org/W3202616165
# Processing https://openalex.org/W3202722289
# Processing https://openalex.org/W3204672706
# Processing https://openalex.org/W3204735205
# Processing https://openalex.org/W3207067564
# Processing https://openalex.org/W3207371012
# Processing https://openalex.org/W3207400243
# Processing https://openalex.org/W3208534945
# Processing https://openalex.org/W3210465688
# Processing https://openalex.org/W3211027916
# Processing https://openalex.org/W3214804213
# Processing https://openalex.org/W3216038618
# Processing https://openalex.org/W3216509343
# Processing https://openalex.org/W325124896
# Processing https://openalex.org/W37448061
# Processing https://openalex.org/W4200297537
# Processing https://openalex.org/W4205360523
# Processing https://openalex.org/W4205552064
# Processing https://openalex.org/W4205619119
# Processing https://openalex.org/W4205731136
# Processing https://openalex.org/W4206194690
# Processing https://openalex.org/W4210953259
# Processing https://openalex.org/W4211263339
# Processing https://openalex.org/W4212888016
# Processing https://openalex.org/W4220692802
# Processing https://openalex.org/W4220732045
# Processing https://openalex.org/W4225276593
# Processing https://openalex.org/W4226345407
# Processing https://openalex.org/W4230356224
# Processing https://openalex.org/W4230700148
# Processing https://openalex.org/W4230711751
# Processing https://openalex.org/W4232769139
# Processing https://openalex.org/W4238048379
# Processing https://openalex.org/W4241858005
# Processing https://openalex.org/W4247667710
# Processing https://openalex.org/W4252430879
# Processing https://openalex.org/W4252745096
# Processing https://openalex.org/W4252952688
# Processing https://openalex.org/W4281690951
# Processing https://openalex.org/W4282557620
# Processing https://openalex.org/W4283657131
# Processing https://openalex.org/W4283764937
# Processing https://openalex.org/W4285024880
# Processing https://openalex.org/W4285199241
# Processing https://openalex.org/W4285249755
# Processing https://openalex.org/W4285263003
# Processing https://openalex.org/W4285483025
# Processing https://openalex.org/W4286458987
# Processing https://openalex.org/W4289824063
# Processing https://openalex.org/W4293041566
# Processing https://openalex.org/W4293190917
# Processing https://openalex.org/W4293801681
# Processing https://openalex.org/W4295766715
# Processing https://openalex.org/W4296277673
# Processing https://openalex.org/W4300073440
# Processing https://openalex.org/W4300951185
# Processing https://openalex.org/W4304172618
# Processing https://openalex.org/W4307156538
# Processing https://openalex.org/W4307711555
# Processing https://openalex.org/W4307723330
# Processing https://openalex.org/W4308908946
# Processing https://openalex.org/W4312204683
# Processing https://openalex.org/W4312419656
# Processing https://openalex.org/W4312651175
# Processing https://openalex.org/W4312705867
# Processing https://openalex.org/W4312802865
# Processing https://openalex.org/W4312805135
# Processing https://openalex.org/W4312882163
# Processing https://openalex.org/W4320148496
# Processing https://openalex.org/W4322624816
# Processing https://openalex.org/W4324121632
# Processing https://openalex.org/W4327519823
# Processing https://openalex.org/W4361000524
# Processing https://openalex.org/W4361214653
# Processing https://openalex.org/W4361974330
# Processing https://openalex.org/W4361988923
# Processing https://openalex.org/W4362499633
# Processing https://openalex.org/W4362611983
# Processing https://openalex.org/W4364368805
# Processing https://openalex.org/W4366085258
# Processing https://openalex.org/W4367052625
# Processing https://openalex.org/W4367597654
# Processing https://openalex.org/W4377002343
# Processing https://openalex.org/W4377834046
# Processing https://openalex.org/W4381512763
# Processing https://openalex.org/W4381660505
# Processing https://openalex.org/W4381666160
# Processing https://openalex.org/W4381736130
# Processing https://openalex.org/W4382807722
# Processing https://openalex.org/W4383346553
# Processing https://openalex.org/W4384133380
# Processing https://openalex.org/W4385213642
# Processing https://openalex.org/W4385260730
# Processing https://openalex.org/W4385494974
# Processing https://openalex.org/W4385782198
# Processing https://openalex.org/W4386094306
# Processing https://openalex.org/W4386370708
# Processing https://openalex.org/W4386491507
# Processing https://openalex.org/W4386929517
# Processing https://openalex.org/W4387158607
# Processing https://openalex.org/W4387172619
# Processing https://openalex.org/W4387195562
# Processing https://openalex.org/W4387912130
# Processing https://openalex.org/W4388626236
# Processing https://openalex.org/W4388724660
# Processing https://openalex.org/W4388938469
# Processing https://openalex.org/W4390066466
# Processing https://openalex.org/W4390145267
# Processing https://openalex.org/W439017983
# Processing https://openalex.org/W4390487374
# Processing https://openalex.org/W4390693054
# Processing https://openalex.org/W4390870445
# Processing https://openalex.org/W4390920600
# Processing https://openalex.org/W4391308576
# Processing https://openalex.org/W4391619986
# Processing https://openalex.org/W4391772409
# Processing https://openalex.org/W4392135119
# Processing https://openalex.org/W4392341912
# Processing https://openalex.org/W4392865012
# Processing https://openalex.org/W4394017071
# Processing https://openalex.org/W4394797139
# Processing https://openalex.org/W4395463994
# Processing https://openalex.org/W4395466247
# Processing https://openalex.org/W4396530482
# Processing https://openalex.org/W4396596924
# Processing https://openalex.org/W4399290172
# Processing https://openalex.org/W4399323633
# Processing https://openalex.org/W4399529338
# Processing https://openalex.org/W4401067024
# Processing https://openalex.org/W4401171797
# Processing https://openalex.org/W4401242778
# Processing https://openalex.org/W4401327824
# Processing https://openalex.org/W4401845594
# Processing https://openalex.org/W4401871424
# Processing https://openalex.org/W4402018025
# Processing https://openalex.org/W4402066912
# Processing https://openalex.org/W4402314342
# Processing https://openalex.org/W4402546895
# Processing https://openalex.org/W4402923847
# Processing https://openalex.org/W4402986304
# Processing https://openalex.org/W4403370613
# Processing https://openalex.org/W4403660177
# Processing https://openalex.org/W4404002973
# Processing https://openalex.org/W4404109958
# Processing https://openalex.org/W4405654739
# Processing https://openalex.org/W4405920878
# Processing https://openalex.org/W4406103194
# Processing https://openalex.org/W4406151692
# Processing https://openalex.org/W4406632693
# Processing https://openalex.org/W4407152405
# Processing https://openalex.org/W4407463226
# Processing https://openalex.org/W59453117
# Processing https://openalex.org/W623596649
# Processing https://openalex.org/W70509848
# Processing https://openalex.org/W765699370
# Processing https://openalex.org/W85222481
# Processing https://openalex.org/W8680042

# %%
cat_df = pd.DataFrame(cat.items(), columns=['id', 'result'])
cat_df[['method_cat', 'method_type']] = cat_df['result'].apply(lambda x: pd.Series(json.loads(x)))
cat_df = cat_df.drop(columns=['result'])
# cat_df.to_csv(f'{path}/results/methods_categories_617_withTitle.csv', index=False)

# %%
estimated_costs_df = pd.DataFrame(estimated_costs.items(), columns=['id', 'cost'])
# estimated_costs_df.to_csv(f'{path}/results/methods_estimated_costs_617_withTitle.csv', index=False)

# %%
print(estimated_costs_df['cost'].sum().round(3), 'Euros')
# Out:
# 2.288 Euros

# %% [markdown]
# ## Data Type

# %%
import logging

cat = {}
estimated_costs = {}

for i, row in df.iterrows(): 
# for i, row in df[~df.index.isin(cat.keys())].iterrows():  # Only process rows without those already in 'cat'
    abs = row['abs'].strip()
    abs_clean = clean_abs(abs)
    print(f'Processing {row.id}')
    start_time = time.time()
    completion = openai_client.beta.chat.completions.parse(
            model= gpt_model,
            messages=[
                { 
                "role": "assistant",
                "content": "You are a research assistant in the Social Sciences domain. I, the researcher, have an abstract of a paper that studied inter/multi generational wealth/income/earning mobility. I want you to categorize the datasets that the paper used based on the abstract."
                
                },
                {
                    "role": "user", 
                    "content":f""" 
                            ```Title: {row['title']}    
                                               
                            ```Abstracts
                            {abs_clean}
                            ```
                            First, recognize the types of datasets the papers used based on the abstracts. 
                            Does it belong to any of the following categories?
                            1.	Panel/Longitudinal Surveys
                            2.	Administrative/Registry Data
                            3.	National Survey Data
                            4.	Opportunity Atlas
                            5.	Natural/Experimental Data
                            6.	Linked Administrative Data
                            7.	International Panel Data
                            8.	Rich List Data
                            9.	University/Institution Data
                            10.	Pseudo-Panel/Household Budget Survey
                            11.	Archival/Historical Data
                            12.	Big Data
                            13.	No dataset
                            14.	Others
                            
                            Return the category that the type(s) belong to as a number, and the exact dataset name if possible. For example, if it belongs to '1', return also the name such as '2015 UK Longitudinal Survey on Wealth Mobility'. 
                            Don't repeat the name of category here like 'Panel/Longitudinal Surveys - 2015 UK Longitudinal Survey on Wealth Mobility'.
                            If the dataset does not belong to any category, return '14' and the exact dataset name.
                            If the paper does not use any dataset, return '13' and N/A as the exact dataset name.
                            """
                }
            ],
            response_format=GetCat,
        )
    results = completion.choices[0].message.content
    tokens_prompt = completion.usage.prompt_tokens
    tokens_completion = completion.usage.completion_tokens
    cost = estimate_cost(tokens_prompt, tokens_completion, model=gpt_model)
    estimated_costs[i] = cost
    cat[i] = results   
        
logging.info('✅ Done! The process time is:', time.time()-start_time)
# Out:
# Processing https://openalex.org/W2564827629
# Processing https://openalex.org/W2117407660
# Processing https://openalex.org/W1515121029
# Processing https://openalex.org/W1966505070
# Processing https://openalex.org/W3041900243
# Processing https://openalex.org/W2508091509
# Processing https://openalex.org/W4393244952
# Processing https://openalex.org/W3125905928
# Processing https://openalex.org/W3208235548
# Processing https://openalex.org/W2411230938
# Processing https://openalex.org/W2912277864
# Processing https://openalex.org/W3122728969
# Processing https://openalex.org/W3166017557
# Processing https://openalex.org/W2049884882
# Processing https://openalex.org/W4289222991
# Processing https://openalex.org/W1994031345
# Processing https://openalex.org/W2460486083
# Processing https://openalex.org/W3201233520
# Processing https://openalex.org/W2164455384
# Processing https://openalex.org/W1994583502
# Processing https://openalex.org/W2148814768
# Processing https://openalex.org/W2470832101
# Processing https://openalex.org/W2123210148
# Processing https://openalex.org/W2008396968
# Processing https://openalex.org/W2802089178
# Processing https://openalex.org/W3045264130
# Processing https://openalex.org/W2613688294
# Processing https://openalex.org/W1983053572
# Processing https://openalex.org/W2079089263
# Processing https://openalex.org/W2042572864
# Processing https://openalex.org/W2912008487
# Processing https://openalex.org/W4280580662
# Processing https://openalex.org/W3018625260
# Processing https://openalex.org/W3165956734
# Processing https://openalex.org/W1993125614
# Processing https://openalex.org/W4407738440
# Processing https://openalex.org/W3143516863
# Processing https://openalex.org/W3127732452
# Processing https://openalex.org/W4234924712
# Processing https://openalex.org/W3123290206
# Processing https://openalex.org/W4289538664
# Processing https://openalex.org/W3189916381
# Processing https://openalex.org/W2337892695
# Processing https://openalex.org/W3088079582
# Processing https://openalex.org/W3027769937
# Processing https://openalex.org/W4213429281
# Processing https://openalex.org/W4238028113
# Processing https://openalex.org/W4295122648
# Processing https://openalex.org/W2119977186
# Processing https://openalex.org/W2159878756
# Processing https://openalex.org/W2419212734
# Processing https://openalex.org/W2056728055
# Processing https://openalex.org/W48048703
# Processing https://openalex.org/W2004570201
# Processing https://openalex.org/W2146082360
# Processing https://openalex.org/W4403898265
# Processing https://openalex.org/W1504875321
# Processing https://openalex.org/W4391164542
# Processing https://openalex.org/W4212975927
# Processing https://openalex.org/W4381889820
# Processing https://openalex.org/W3161971993
# Processing https://openalex.org/W2569989626
# Processing https://openalex.org/W3121558866
# Processing https://openalex.org/W4242326182
# Processing https://openalex.org/W2556000214
# Processing https://openalex.org/W4214604726
# Processing https://openalex.org/W632219639
# Processing https://openalex.org/W2546674699
# Processing https://openalex.org/W3175158828
# Processing https://openalex.org/W3183234565
# Processing https://openalex.org/W2905819002
# Processing https://openalex.org/W4205561583
# Processing https://openalex.org/W4308132439
# Processing https://openalex.org/W1020822704
# Processing https://openalex.org/W115198923
# Processing https://openalex.org/W1444704346
# Processing https://openalex.org/W146920992
# Processing https://openalex.org/W1502476793
# Processing https://openalex.org/W1504828284
# Processing https://openalex.org/W1510224607
# Processing https://openalex.org/W1521709394
# Processing https://openalex.org/W1523582143
# Processing https://openalex.org/W1524458346
# Processing https://openalex.org/W1525853258
# Processing https://openalex.org/W1527079419
# Processing https://openalex.org/W1545014524
# Processing https://openalex.org/W1546068527
# Processing https://openalex.org/W1556385061
# Processing https://openalex.org/W1557569468
# Processing https://openalex.org/W1559271355
# Processing https://openalex.org/W1575557529
# Processing https://openalex.org/W1577807578
# Processing https://openalex.org/W1578919155
# Processing https://openalex.org/W1580804840
# Processing https://openalex.org/W1581391655
# Processing https://openalex.org/W1583265181
# Processing https://openalex.org/W1648451562
# Processing https://openalex.org/W167868874
# Processing https://openalex.org/W1724441452
# Processing https://openalex.org/W1737762879
# Processing https://openalex.org/W1748686498
# Processing https://openalex.org/W1763036350
# Processing https://openalex.org/W1770740881
# Processing https://openalex.org/W1791196730
# Processing https://openalex.org/W1792190074
# Processing https://openalex.org/W1842793959
# Processing https://openalex.org/W1862838271
# Processing https://openalex.org/W1882444807
# Processing https://openalex.org/W1885260769
# Processing https://openalex.org/W1896316165
# Processing https://openalex.org/W1896704912
# Processing https://openalex.org/W1912659445
# Processing https://openalex.org/W191471880
# Processing https://openalex.org/W1947133949
# Processing https://openalex.org/W1963513809
# Processing https://openalex.org/W1967097718
# Processing https://openalex.org/W1969182931
# Processing https://openalex.org/W1969197029
# Processing https://openalex.org/W1971213371
# Processing https://openalex.org/W1974242925
# Processing https://openalex.org/W1978270348
# Processing https://openalex.org/W1984800654
# Processing https://openalex.org/W1985674062
# Processing https://openalex.org/W1988669335
# Processing https://openalex.org/W1989526535
# Processing https://openalex.org/W1993705293
# Processing https://openalex.org/W1993865286
# Processing https://openalex.org/W1994441718
# Processing https://openalex.org/W1997361840
# Processing https://openalex.org/W1998586807
# Processing https://openalex.org/W2003050456
# Processing https://openalex.org/W2003514985
# Processing https://openalex.org/W2008560119
# Processing https://openalex.org/W2009388710
# Processing https://openalex.org/W2009549340
# Processing https://openalex.org/W2009705015
# Processing https://openalex.org/W2009897266
# Processing https://openalex.org/W2010545686
# Processing https://openalex.org/W2011405670
# Processing https://openalex.org/W2012592263
# Processing https://openalex.org/W2017256370
# Processing https://openalex.org/W2018079782
# Processing https://openalex.org/W2018386129
# Processing https://openalex.org/W2022256544
# Processing https://openalex.org/W2025903092
# Processing https://openalex.org/W2027209063
# Processing https://openalex.org/W2028148226
# Processing https://openalex.org/W2028289362
# Processing https://openalex.org/W2030719283
# Processing https://openalex.org/W2034417760
# Processing https://openalex.org/W2037234295
# Processing https://openalex.org/W2037428382
# Processing https://openalex.org/W2038719374
# Processing https://openalex.org/W2039841106
# Processing https://openalex.org/W2044900547
# Processing https://openalex.org/W2048745299
# Processing https://openalex.org/W2049773875
# Processing https://openalex.org/W2051645598
# Processing https://openalex.org/W2053034611
# Processing https://openalex.org/W2055372720
# Processing https://openalex.org/W2056823769
# Processing https://openalex.org/W2068645718
# Processing https://openalex.org/W2078842385
# Processing https://openalex.org/W2079691849
# Processing https://openalex.org/W2082418718
# Processing https://openalex.org/W2091916425
# Processing https://openalex.org/W2094244093
# Processing https://openalex.org/W2096204191
# Processing https://openalex.org/W2097343718
# Processing https://openalex.org/W2099874214
# Processing https://openalex.org/W2105584013
# Processing https://openalex.org/W2106387882
# Processing https://openalex.org/W2107393980
# Processing https://openalex.org/W2108734997
# Processing https://openalex.org/W2116568238
# Processing https://openalex.org/W2117544103
# Processing https://openalex.org/W2118931737
# Processing https://openalex.org/W2119455293
# Processing https://openalex.org/W2119587652
# Processing https://openalex.org/W2120158174
# Processing https://openalex.org/W2122216841
# Processing https://openalex.org/W2122845532
# Processing https://openalex.org/W2123253365
# Processing https://openalex.org/W2124465354
# Processing https://openalex.org/W2125337016
# Processing https://openalex.org/W2127281421
# Processing https://openalex.org/W2131012252
# Processing https://openalex.org/W2132728629
# Processing https://openalex.org/W2133143546
# Processing https://openalex.org/W2133321662
# Processing https://openalex.org/W2133450989
# Processing https://openalex.org/W2134426017
# Processing https://openalex.org/W2134725625
# Processing https://openalex.org/W2144050291
# Processing https://openalex.org/W2151222191
# Processing https://openalex.org/W2153943844
# Processing https://openalex.org/W2155246844
# Processing https://openalex.org/W2157585414
# Processing https://openalex.org/W2158055684
# Processing https://openalex.org/W2159953986
# Processing https://openalex.org/W2159988399
# Processing https://openalex.org/W2170708007
# Processing https://openalex.org/W2171543589
# Processing https://openalex.org/W2181742113
# Processing https://openalex.org/W2182279624
# Processing https://openalex.org/W2182749524
# Processing https://openalex.org/W2184044297
# Processing https://openalex.org/W2184450311
# Processing https://openalex.org/W2184544484
# Processing https://openalex.org/W2186374397
# Processing https://openalex.org/W2187204840
# Processing https://openalex.org/W2188355739
# Processing https://openalex.org/W2198347083
# Processing https://openalex.org/W2208157789
# Processing https://openalex.org/W2208317766
# Processing https://openalex.org/W2210747677
# Processing https://openalex.org/W2216308767
# Processing https://openalex.org/W2229381819
# Processing https://openalex.org/W2237492881
# Processing https://openalex.org/W2244928658
# Processing https://openalex.org/W2258354779
# Processing https://openalex.org/W2261420935
# Processing https://openalex.org/W2262410031
# Processing https://openalex.org/W2285151281
# Processing https://openalex.org/W2288802977
# Processing https://openalex.org/W2291516288
# Processing https://openalex.org/W2292189473
# Processing https://openalex.org/W2298141770
# Processing https://openalex.org/W2302816456
# Processing https://openalex.org/W2310208630
# Processing https://openalex.org/W2320409419
# Processing https://openalex.org/W2322954441
# Processing https://openalex.org/W2332279578
# Processing https://openalex.org/W2351358614
# Processing https://openalex.org/W2351966756
# Processing https://openalex.org/W2353487644
# Processing https://openalex.org/W2353503414
# Processing https://openalex.org/W2353931744
# Processing https://openalex.org/W2355555430
# Processing https://openalex.org/W2363649169
# Processing https://openalex.org/W2364400020
# Processing https://openalex.org/W2364722826
# Processing https://openalex.org/W2365705769
# Processing https://openalex.org/W2366816539
# Processing https://openalex.org/W2368218525
# Processing https://openalex.org/W2375187415
# Processing https://openalex.org/W2376609871
# Processing https://openalex.org/W2378057080
# Processing https://openalex.org/W2380359989
# Processing https://openalex.org/W2387291285
# Processing https://openalex.org/W2388800308
# Processing https://openalex.org/W2389521723
# Processing https://openalex.org/W2403977165
# Processing https://openalex.org/W2473722593
# Processing https://openalex.org/W2476394513
# Processing https://openalex.org/W2482682982
# Processing https://openalex.org/W2485689150
# Processing https://openalex.org/W2495276003
# Processing https://openalex.org/W2507475885
# Processing https://openalex.org/W2512952691
# Processing https://openalex.org/W2527995213
# Processing https://openalex.org/W2544001857
# Processing https://openalex.org/W2553521091
# Processing https://openalex.org/W2561736289
# Processing https://openalex.org/W2565185528
# Processing https://openalex.org/W2580182246
# Processing https://openalex.org/W2587329652
# Processing https://openalex.org/W2587720673
# Processing https://openalex.org/W2588161629
# Processing https://openalex.org/W2589434942
# Processing https://openalex.org/W2592479289
# Processing https://openalex.org/W2595264819
# Processing https://openalex.org/W2596999048
# Processing https://openalex.org/W2598091349
# Processing https://openalex.org/W2598656573
# Processing https://openalex.org/W2602849344
# Processing https://openalex.org/W2612875108
# Processing https://openalex.org/W2619151633
# Processing https://openalex.org/W2625426831
# Processing https://openalex.org/W2625992765
# Processing https://openalex.org/W2635740930
# Processing https://openalex.org/W2663861583
# Processing https://openalex.org/W267019868
# Processing https://openalex.org/W2716435981
# Processing https://openalex.org/W2741490491
# Processing https://openalex.org/W2756659966
# Processing https://openalex.org/W2761614070
# Processing https://openalex.org/W2766173862
# Processing https://openalex.org/W2767134817
# Processing https://openalex.org/W2767739989
# Processing https://openalex.org/W2772867153
# Processing https://openalex.org/W2773177589
# Processing https://openalex.org/W2773358030
# Processing https://openalex.org/W2780097379
# Processing https://openalex.org/W2789684694
# Processing https://openalex.org/W2794220255
# Processing https://openalex.org/W2801737043
# Processing https://openalex.org/W2804095451
# Processing https://openalex.org/W2804958844
# Processing https://openalex.org/W2806349642
# Processing https://openalex.org/W2807800750
# Processing https://openalex.org/W2811219136
# Processing https://openalex.org/W2883024550
# Processing https://openalex.org/W2887573038
# Processing https://openalex.org/W2889122466
# Processing https://openalex.org/W2890540479
# Processing https://openalex.org/W2890591802
# Processing https://openalex.org/W2890853717
# Processing https://openalex.org/W2891903686
# Processing https://openalex.org/W2895165109
# Processing https://openalex.org/W2896751489
# Processing https://openalex.org/W2897475839
# Processing https://openalex.org/W2900408224
# Processing https://openalex.org/W2902789768
# Processing https://openalex.org/W2906080883
# Processing https://openalex.org/W2908577399
# Processing https://openalex.org/W291004932
# Processing https://openalex.org/W2913916335
# Processing https://openalex.org/W2914094440
# Processing https://openalex.org/W2918831213
# Processing https://openalex.org/W2920476039
# Processing https://openalex.org/W2921069773
# Processing https://openalex.org/W2921143263
# Processing https://openalex.org/W2921237584
# Processing https://openalex.org/W2921712035
# Processing https://openalex.org/W2922039017
# Processing https://openalex.org/W2922209108
# Processing https://openalex.org/W2922684064
# Processing https://openalex.org/W2922736319
# Processing https://openalex.org/W2924600205
# Processing https://openalex.org/W2931489399
# Processing https://openalex.org/W2933369931
# Processing https://openalex.org/W2936910510
# Processing https://openalex.org/W2938378096
# Processing https://openalex.org/W2940947093
# Processing https://openalex.org/W2942948331
# Processing https://openalex.org/W2943104001
# Processing https://openalex.org/W2943421593
# Processing https://openalex.org/W2943543771
# Processing https://openalex.org/W2944091914
# Processing https://openalex.org/W2947666646
# Processing https://openalex.org/W2953817338
# Processing https://openalex.org/W2955018254
# Processing https://openalex.org/W2963918180
# Processing https://openalex.org/W2965558093
# Processing https://openalex.org/W2966414435
# Processing https://openalex.org/W2967279307
# Processing https://openalex.org/W2968697195
# Processing https://openalex.org/W2971359031
# Processing https://openalex.org/W2972798438
# Processing https://openalex.org/W2978816005
# Processing https://openalex.org/W2980728415
# Processing https://openalex.org/W2981344849
# Processing https://openalex.org/W2984996373
# Processing https://openalex.org/W2986629221
# Processing https://openalex.org/W2997562221
# Processing https://openalex.org/W3000604125
# Processing https://openalex.org/W3001385022
# Processing https://openalex.org/W3001811947
# Processing https://openalex.org/W3007051557
# Processing https://openalex.org/W3008379420
# Processing https://openalex.org/W3021741550
# Processing https://openalex.org/W3022704615
# Processing https://openalex.org/W3025499686
# Processing https://openalex.org/W3025676006
# Processing https://openalex.org/W3026679872
# Processing https://openalex.org/W3032637579
# Processing https://openalex.org/W3033501614
# Processing https://openalex.org/W3033668572
# Processing https://openalex.org/W3033929493
# Processing https://openalex.org/W3037216812
# Processing https://openalex.org/W3037705751
# Processing https://openalex.org/W3039577330
# Processing https://openalex.org/W3039606322
# Processing https://openalex.org/W3043515736
# Processing https://openalex.org/W3043938586
# Processing https://openalex.org/W3044383046
# Processing https://openalex.org/W3044954030
# Processing https://openalex.org/W3049173530
# Processing https://openalex.org/W3080387614
# Processing https://openalex.org/W3084113281
# Processing https://openalex.org/W3093752946
# Processing https://openalex.org/W3094369084
# Processing https://openalex.org/W3099122721
# Processing https://openalex.org/W3105823174
# Processing https://openalex.org/W3109347625
# Processing https://openalex.org/W3113905449
# Processing https://openalex.org/W3119775080
# Processing https://openalex.org/W3120292600
# Processing https://openalex.org/W3121144081
# Processing https://openalex.org/W3121217472
# Processing https://openalex.org/W3121421182
# Processing https://openalex.org/W3121518780
# Processing https://openalex.org/W3121545129
# Processing https://openalex.org/W3121626177
# Processing https://openalex.org/W3121694509
# Processing https://openalex.org/W3121808914
# Processing https://openalex.org/W3122167690
# Processing https://openalex.org/W3122768301
# Processing https://openalex.org/W3122884517
# Processing https://openalex.org/W3123195152
# Processing https://openalex.org/W3123202179
# Processing https://openalex.org/W3123505781
# Processing https://openalex.org/W3123563038
# Processing https://openalex.org/W3123638740
# Processing https://openalex.org/W3123816425
# Processing https://openalex.org/W3124044027
# Processing https://openalex.org/W3124226182
# Processing https://openalex.org/W3124279434
# Processing https://openalex.org/W3124358677
# Processing https://openalex.org/W3124369867
# Processing https://openalex.org/W3124481018
# Processing https://openalex.org/W3124527946
# Processing https://openalex.org/W3124550008
# Processing https://openalex.org/W3124621746
# Processing https://openalex.org/W3124992314
# Processing https://openalex.org/W3125052842
# Processing https://openalex.org/W3125112178
# Processing https://openalex.org/W3125155430
# Processing https://openalex.org/W3125318571
# Processing https://openalex.org/W3125330545
# Processing https://openalex.org/W3125359030
# Processing https://openalex.org/W3125406097
# Processing https://openalex.org/W3125643021
# Processing https://openalex.org/W3125844548
# Processing https://openalex.org/W3125856458
# Processing https://openalex.org/W3126032812
# Processing https://openalex.org/W3128702014
# Processing https://openalex.org/W3129579937
# Processing https://openalex.org/W3132136530
# Processing https://openalex.org/W3136260651
# Processing https://openalex.org/W3136420028
# Processing https://openalex.org/W3142916655
# Processing https://openalex.org/W3145594932
# Processing https://openalex.org/W3147268152
# Processing https://openalex.org/W3150419855
# Processing https://openalex.org/W3156722884
# Processing https://openalex.org/W3163153651
# Processing https://openalex.org/W3163537223
# Processing https://openalex.org/W3168728451
# Processing https://openalex.org/W3169577729
# Processing https://openalex.org/W3170592684
# Processing https://openalex.org/W3171039042
# Processing https://openalex.org/W3176622639
# Processing https://openalex.org/W3176921257
# Processing https://openalex.org/W3178385122
# Processing https://openalex.org/W3181553951
# Processing https://openalex.org/W3181973673
# Processing https://openalex.org/W3182550406
# Processing https://openalex.org/W3184422859
# Processing https://openalex.org/W3185155858
# Processing https://openalex.org/W3186457560
# Processing https://openalex.org/W3189747191
# Processing https://openalex.org/W3190097825
# Processing https://openalex.org/W3190102834
# Processing https://openalex.org/W3192903419
# Processing https://openalex.org/W3195123941
# Processing https://openalex.org/W3197901707
# Processing https://openalex.org/W3198616739
# Processing https://openalex.org/W3202153609
# Processing https://openalex.org/W3202616165
# Processing https://openalex.org/W3202722289
# Processing https://openalex.org/W3204672706
# Processing https://openalex.org/W3204735205
# Processing https://openalex.org/W3207067564
# Processing https://openalex.org/W3207371012
# Processing https://openalex.org/W3207400243
# Processing https://openalex.org/W3208534945
# Processing https://openalex.org/W3210465688
# Processing https://openalex.org/W3211027916
# Processing https://openalex.org/W3214804213
# Processing https://openalex.org/W3216038618
# Processing https://openalex.org/W3216509343
# Processing https://openalex.org/W325124896
# Processing https://openalex.org/W37448061
# Processing https://openalex.org/W4200297537
# Processing https://openalex.org/W4205360523
# Processing https://openalex.org/W4205552064
# Processing https://openalex.org/W4205619119
# Processing https://openalex.org/W4205731136
# Processing https://openalex.org/W4206194690
# Processing https://openalex.org/W4210953259
# Processing https://openalex.org/W4211263339
# Processing https://openalex.org/W4212888016
# Processing https://openalex.org/W4220692802
# Processing https://openalex.org/W4220732045
# Processing https://openalex.org/W4225276593
# Processing https://openalex.org/W4226345407
# Processing https://openalex.org/W4230356224
# Processing https://openalex.org/W4230700148
# Processing https://openalex.org/W4230711751
# Processing https://openalex.org/W4232769139
# Processing https://openalex.org/W4238048379
# Processing https://openalex.org/W4241858005
# Processing https://openalex.org/W4247667710
# Processing https://openalex.org/W4252430879
# Processing https://openalex.org/W4252745096
# Processing https://openalex.org/W4252952688
# Processing https://openalex.org/W4281690951
# Processing https://openalex.org/W4282557620
# Processing https://openalex.org/W4283657131
# Processing https://openalex.org/W4283764937
# Processing https://openalex.org/W4285024880
# Processing https://openalex.org/W4285199241
# Processing https://openalex.org/W4285249755
# Processing https://openalex.org/W4285263003
# Processing https://openalex.org/W4285483025
# Processing https://openalex.org/W4286458987
# Processing https://openalex.org/W4289824063
# Processing https://openalex.org/W4293041566
# Processing https://openalex.org/W4293190917
# Processing https://openalex.org/W4293801681
# Processing https://openalex.org/W4295766715
# Processing https://openalex.org/W4296277673
# Processing https://openalex.org/W4300073440
# Processing https://openalex.org/W4300951185
# Processing https://openalex.org/W4304172618
# Processing https://openalex.org/W4307156538
# Processing https://openalex.org/W4307711555
# Processing https://openalex.org/W4307723330
# Processing https://openalex.org/W4308908946
# Processing https://openalex.org/W4312204683
# Processing https://openalex.org/W4312419656
# Processing https://openalex.org/W4312651175
# Processing https://openalex.org/W4312705867
# Processing https://openalex.org/W4312802865
# Processing https://openalex.org/W4312805135
# Processing https://openalex.org/W4312882163
# Processing https://openalex.org/W4320148496
# Processing https://openalex.org/W4322624816
# Processing https://openalex.org/W4324121632
# Processing https://openalex.org/W4327519823
# Processing https://openalex.org/W4361000524
# Processing https://openalex.org/W4361214653
# Processing https://openalex.org/W4361974330
# Processing https://openalex.org/W4361988923
# Processing https://openalex.org/W4362499633
# Processing https://openalex.org/W4362611983
# Processing https://openalex.org/W4364368805
# Processing https://openalex.org/W4366085258
# Processing https://openalex.org/W4367052625
# Processing https://openalex.org/W4367597654
# Processing https://openalex.org/W4377002343
# Processing https://openalex.org/W4377834046
# Processing https://openalex.org/W4381512763
# Processing https://openalex.org/W4381660505
# Processing https://openalex.org/W4381666160
# Processing https://openalex.org/W4381736130
# Processing https://openalex.org/W4382807722
# Processing https://openalex.org/W4383346553
# Processing https://openalex.org/W4384133380
# Processing https://openalex.org/W4385213642
# Processing https://openalex.org/W4385260730
# Processing https://openalex.org/W4385494974
# Processing https://openalex.org/W4385782198
# Processing https://openalex.org/W4386094306
# Processing https://openalex.org/W4386370708
# Processing https://openalex.org/W4386491507
# Processing https://openalex.org/W4386929517
# Processing https://openalex.org/W4387158607
# Processing https://openalex.org/W4387172619
# Processing https://openalex.org/W4387195562
# Processing https://openalex.org/W4387912130
# Processing https://openalex.org/W4388626236
# Processing https://openalex.org/W4388724660
# Processing https://openalex.org/W4388938469
# Processing https://openalex.org/W4390066466
# Processing https://openalex.org/W4390145267
# Processing https://openalex.org/W439017983
# Processing https://openalex.org/W4390487374
# Processing https://openalex.org/W4390693054
# Processing https://openalex.org/W4390870445
# Processing https://openalex.org/W4390920600
# Processing https://openalex.org/W4391308576
# Processing https://openalex.org/W4391619986
# Processing https://openalex.org/W4391772409
# Processing https://openalex.org/W4392135119
# Processing https://openalex.org/W4392341912
# Processing https://openalex.org/W4392865012
# Processing https://openalex.org/W4394017071
# Processing https://openalex.org/W4394797139
# Processing https://openalex.org/W4395463994
# Processing https://openalex.org/W4395466247
# Processing https://openalex.org/W4396530482
# Processing https://openalex.org/W4396596924
# Processing https://openalex.org/W4399290172
# Processing https://openalex.org/W4399323633
# Processing https://openalex.org/W4399529338
# Processing https://openalex.org/W4401067024
# Processing https://openalex.org/W4401171797
# Processing https://openalex.org/W4401242778
# Processing https://openalex.org/W4401327824
# Processing https://openalex.org/W4401845594
# Processing https://openalex.org/W4401871424
# Processing https://openalex.org/W4402018025
# Processing https://openalex.org/W4402066912
# Processing https://openalex.org/W4402314342
# Processing https://openalex.org/W4402546895
# Processing https://openalex.org/W4402923847
# Processing https://openalex.org/W4402986304
# Processing https://openalex.org/W4403370613
# Processing https://openalex.org/W4403660177
# Processing https://openalex.org/W4404002973
# Processing https://openalex.org/W4404109958
# Processing https://openalex.org/W4405654739
# Processing https://openalex.org/W4405920878
# Processing https://openalex.org/W4406103194
# Processing https://openalex.org/W4406151692
# Processing https://openalex.org/W4406632693
# Processing https://openalex.org/W4407152405
# Processing https://openalex.org/W4407463226
# Processing https://openalex.org/W59453117
# Processing https://openalex.org/W623596649
# Processing https://openalex.org/W70509848
# Processing https://openalex.org/W765699370
# Processing https://openalex.org/W85222481
# Processing https://openalex.org/W8680042

# %%
cat_df = pd.DataFrame(cat.items(), columns=['id', 'result'])
cat_df[['data_cat', 'data_type']] = cat_df['result'].apply(lambda x: pd.Series(json.loads(x)))
cat_df = cat_df.drop(columns=['result'])
cat_df.to_csv(f'{path}/results/datatypes_categories_617_withTitle.csv', index=False)

# %%
estimated_costs_df = pd.DataFrame(estimated_costs.items(), columns=['id', 'cost'])
estimated_costs_df.to_csv(f'{path}/results/datatypes_estimated_costs_617_withTitle.csv', index=False)

# %%
print(estimated_costs_df['cost'].sum().round(3), 'Euros')
# Out:
# 2.14 Euros

# %% [markdown]
# ## RQ Type

# %%
import logging

cat = {}
estimated_costs = {}

for i, row in df.iterrows(): 
# for i, row in df[~df.index.isin(cat.keys())].iterrows():  # Only process rows without those already in 'cat'
    abs = row['abs'].strip()
    abs_clean = clean_abs(abs)
    print(f'Processing {row.id}')
    start_time = time.time()
    completion = openai_client.beta.chat.completions.parse(
            model= gpt_model,
            messages=[
                { 
                "role": "assistant",
                "content": "You are a research assistant in the Social Sciences domain. I, the researcher, have an abstract of a paper that studied inter/multi generational wealth/income/earning mobility. I want you to categorize the research questions that the paper aimed to answer based on the abstract."
                
                },
                {
                    "role": "user", 
                    "content":f"""
                            ```Title: {row['title']}     
                                               
                            ```Abstracts
                            {abs_clean}
                            ```
                            First, recognize the types of research questions the papers aimed to answer based on the abstracts. 
                            Does it belong to any of the following categories?
                            1.	Measurement and Methodological Advances
                            2.	Empirical Estimates and Determinants
                            3.	Policy, Institutional, and Geographic Impacts
                            4.	Intergenerational Wealth Mobility and Inheritance
                            5.	Demographic Differences in Mobility (Race, Gender, etc.)
                            6.	Mobility and Non-Income Outcomes (Health, Wellbeing, etc.)
                            7.	Theoretical and Structural Models
                            8.	Perceptions of Mobility and Attitudes
                            9.	Others
                            
                            Return the category that the research questions belong to as a number, and the exact research question if possible. 
                            If the dataset does not belong to any category, return '9' and the exact research question.                            """
                }
            ],
            response_format=GetCat,
        )
    results = completion.choices[0].message.content
    tokens_prompt = completion.usage.prompt_tokens
    tokens_completion = completion.usage.completion_tokens
    cost = estimate_cost(tokens_prompt, tokens_completion, model=gpt_model)
    estimated_costs[i] = cost
    cat[i] = results   
        
logging.info('✅ Done! The process time is:', time.time()-start_time)
# Out:
# Processing https://openalex.org/W2564827629
# Processing https://openalex.org/W2117407660
# Processing https://openalex.org/W1515121029
# Processing https://openalex.org/W1966505070
# Processing https://openalex.org/W3041900243
# Processing https://openalex.org/W2508091509
# Processing https://openalex.org/W4393244952
# Processing https://openalex.org/W3125905928
# Processing https://openalex.org/W3208235548
# Processing https://openalex.org/W2411230938
# Processing https://openalex.org/W2912277864
# Processing https://openalex.org/W3122728969
# Processing https://openalex.org/W3166017557
# Processing https://openalex.org/W2049884882
# Processing https://openalex.org/W4289222991
# Processing https://openalex.org/W1994031345
# Processing https://openalex.org/W2460486083
# Processing https://openalex.org/W3201233520
# Processing https://openalex.org/W2164455384
# Processing https://openalex.org/W1994583502
# Processing https://openalex.org/W2148814768
# Processing https://openalex.org/W2470832101
# Processing https://openalex.org/W2123210148
# Processing https://openalex.org/W2008396968
# Processing https://openalex.org/W2802089178
# Processing https://openalex.org/W3045264130
# Processing https://openalex.org/W2613688294
# Processing https://openalex.org/W1983053572
# Processing https://openalex.org/W2079089263
# Processing https://openalex.org/W2042572864
# Processing https://openalex.org/W2912008487
# Processing https://openalex.org/W4280580662
# Processing https://openalex.org/W3018625260
# Processing https://openalex.org/W3165956734
# Processing https://openalex.org/W1993125614
# Processing https://openalex.org/W4407738440
# Processing https://openalex.org/W3143516863
# Processing https://openalex.org/W3127732452
# Processing https://openalex.org/W4234924712
# Processing https://openalex.org/W3123290206
# Processing https://openalex.org/W4289538664
# Processing https://openalex.org/W3189916381
# Processing https://openalex.org/W2337892695
# Processing https://openalex.org/W3088079582
# Processing https://openalex.org/W3027769937
# Processing https://openalex.org/W4213429281
# Processing https://openalex.org/W4238028113
# Processing https://openalex.org/W4295122648
# Processing https://openalex.org/W2119977186
# Processing https://openalex.org/W2159878756
# Processing https://openalex.org/W2419212734
# Processing https://openalex.org/W2056728055
# Processing https://openalex.org/W48048703
# Processing https://openalex.org/W2004570201
# Processing https://openalex.org/W2146082360
# Processing https://openalex.org/W4403898265
# Processing https://openalex.org/W1504875321
# Processing https://openalex.org/W4391164542
# Processing https://openalex.org/W4212975927
# Processing https://openalex.org/W4381889820
# Processing https://openalex.org/W3161971993
# Processing https://openalex.org/W2569989626
# Processing https://openalex.org/W3121558866
# Processing https://openalex.org/W4242326182
# Processing https://openalex.org/W2556000214
# Processing https://openalex.org/W4214604726
# Processing https://openalex.org/W632219639
# Processing https://openalex.org/W2546674699
# Processing https://openalex.org/W3175158828
# Processing https://openalex.org/W3183234565
# Processing https://openalex.org/W2905819002
# Processing https://openalex.org/W4205561583
# Processing https://openalex.org/W4308132439
# Processing https://openalex.org/W1020822704
# Processing https://openalex.org/W115198923
# Processing https://openalex.org/W1444704346
# Processing https://openalex.org/W146920992
# Processing https://openalex.org/W1502476793
# Processing https://openalex.org/W1504828284
# Processing https://openalex.org/W1510224607
# Processing https://openalex.org/W1521709394
# Processing https://openalex.org/W1523582143
# Processing https://openalex.org/W1524458346
# Processing https://openalex.org/W1525853258
# Processing https://openalex.org/W1527079419
# Processing https://openalex.org/W1545014524
# Processing https://openalex.org/W1546068527
# Processing https://openalex.org/W1556385061
# Processing https://openalex.org/W1557569468
# Processing https://openalex.org/W1559271355
# Processing https://openalex.org/W1575557529
# Processing https://openalex.org/W1577807578
# Processing https://openalex.org/W1578919155
# Processing https://openalex.org/W1580804840
# Processing https://openalex.org/W1581391655
# Processing https://openalex.org/W1583265181
# Processing https://openalex.org/W1648451562
# Processing https://openalex.org/W167868874
# Processing https://openalex.org/W1724441452
# Processing https://openalex.org/W1737762879
# Processing https://openalex.org/W1748686498
# Processing https://openalex.org/W1763036350
# Processing https://openalex.org/W1770740881
# Processing https://openalex.org/W1791196730
# Processing https://openalex.org/W1792190074
# Processing https://openalex.org/W1842793959
# Processing https://openalex.org/W1862838271
# Processing https://openalex.org/W1882444807
# Processing https://openalex.org/W1885260769
# Processing https://openalex.org/W1896316165
# Processing https://openalex.org/W1896704912
# Processing https://openalex.org/W1912659445
# Processing https://openalex.org/W191471880
# Processing https://openalex.org/W1947133949
# Processing https://openalex.org/W1963513809
# Processing https://openalex.org/W1967097718
# Processing https://openalex.org/W1969182931
# Processing https://openalex.org/W1969197029
# Processing https://openalex.org/W1971213371
# Processing https://openalex.org/W1974242925
# Processing https://openalex.org/W1978270348
# Processing https://openalex.org/W1984800654
# Processing https://openalex.org/W1985674062
# Processing https://openalex.org/W1988669335
# Processing https://openalex.org/W1989526535
# Processing https://openalex.org/W1993705293
# Processing https://openalex.org/W1993865286
# Processing https://openalex.org/W1994441718
# Processing https://openalex.org/W1997361840
# Processing https://openalex.org/W1998586807
# Processing https://openalex.org/W2003050456
# Processing https://openalex.org/W2003514985
# Processing https://openalex.org/W2008560119
# Processing https://openalex.org/W2009388710
# Processing https://openalex.org/W2009549340
# Processing https://openalex.org/W2009705015
# Processing https://openalex.org/W2009897266
# Processing https://openalex.org/W2010545686
# Processing https://openalex.org/W2011405670
# Processing https://openalex.org/W2012592263
# Processing https://openalex.org/W2017256370
# Processing https://openalex.org/W2018079782
# Processing https://openalex.org/W2018386129
# Processing https://openalex.org/W2022256544
# Processing https://openalex.org/W2025903092
# Processing https://openalex.org/W2027209063
# Processing https://openalex.org/W2028148226
# Processing https://openalex.org/W2028289362
# Processing https://openalex.org/W2030719283
# Processing https://openalex.org/W2034417760
# Processing https://openalex.org/W2037234295
# Processing https://openalex.org/W2037428382
# Processing https://openalex.org/W2038719374
# Processing https://openalex.org/W2039841106
# Processing https://openalex.org/W2044900547
# Processing https://openalex.org/W2048745299
# Processing https://openalex.org/W2049773875
# Processing https://openalex.org/W2051645598
# Processing https://openalex.org/W2053034611
# Processing https://openalex.org/W2055372720
# Processing https://openalex.org/W2056823769
# Processing https://openalex.org/W2068645718
# Processing https://openalex.org/W2078842385
# Processing https://openalex.org/W2079691849
# Processing https://openalex.org/W2082418718
# Processing https://openalex.org/W2091916425
# Processing https://openalex.org/W2094244093
# Processing https://openalex.org/W2096204191
# Processing https://openalex.org/W2097343718
# Processing https://openalex.org/W2099874214
# Processing https://openalex.org/W2105584013
# Processing https://openalex.org/W2106387882
# Processing https://openalex.org/W2107393980
# Processing https://openalex.org/W2108734997
# Processing https://openalex.org/W2116568238
# Processing https://openalex.org/W2117544103
# Processing https://openalex.org/W2118931737
# Processing https://openalex.org/W2119455293
# Processing https://openalex.org/W2119587652
# Processing https://openalex.org/W2120158174
# Processing https://openalex.org/W2122216841
# Processing https://openalex.org/W2122845532
# Processing https://openalex.org/W2123253365
# Processing https://openalex.org/W2124465354
# Processing https://openalex.org/W2125337016
# Processing https://openalex.org/W2127281421
# Processing https://openalex.org/W2131012252
# Processing https://openalex.org/W2132728629
# Processing https://openalex.org/W2133143546
# Processing https://openalex.org/W2133321662
# Processing https://openalex.org/W2133450989
# Processing https://openalex.org/W2134426017
# Processing https://openalex.org/W2134725625
# Processing https://openalex.org/W2144050291
# Processing https://openalex.org/W2151222191
# Processing https://openalex.org/W2153943844
# Processing https://openalex.org/W2155246844
# Processing https://openalex.org/W2157585414
# Processing https://openalex.org/W2158055684
# Processing https://openalex.org/W2159953986
# Processing https://openalex.org/W2159988399
# Processing https://openalex.org/W2170708007
# Processing https://openalex.org/W2171543589
# Processing https://openalex.org/W2181742113
# Processing https://openalex.org/W2182279624
# Processing https://openalex.org/W2182749524
# Processing https://openalex.org/W2184044297
# Processing https://openalex.org/W2184450311
# Processing https://openalex.org/W2184544484
# Processing https://openalex.org/W2186374397
# Processing https://openalex.org/W2187204840
# Processing https://openalex.org/W2188355739
# Processing https://openalex.org/W2198347083
# Processing https://openalex.org/W2208157789
# Processing https://openalex.org/W2208317766
# Processing https://openalex.org/W2210747677
# Processing https://openalex.org/W2216308767
# Processing https://openalex.org/W2229381819
# Processing https://openalex.org/W2237492881
# Processing https://openalex.org/W2244928658
# Processing https://openalex.org/W2258354779
# Processing https://openalex.org/W2261420935
# Processing https://openalex.org/W2262410031
# Processing https://openalex.org/W2285151281
# Processing https://openalex.org/W2288802977
# Processing https://openalex.org/W2291516288
# Processing https://openalex.org/W2292189473
# Processing https://openalex.org/W2298141770
# Processing https://openalex.org/W2302816456
# Processing https://openalex.org/W2310208630
# Processing https://openalex.org/W2320409419
# Processing https://openalex.org/W2322954441
# Processing https://openalex.org/W2332279578
# Processing https://openalex.org/W2351358614
# Processing https://openalex.org/W2351966756
# Processing https://openalex.org/W2353487644
# Processing https://openalex.org/W2353503414
# Processing https://openalex.org/W2353931744
# Processing https://openalex.org/W2355555430
# Processing https://openalex.org/W2363649169
# Processing https://openalex.org/W2364400020
# Processing https://openalex.org/W2364722826
# Processing https://openalex.org/W2365705769
# Processing https://openalex.org/W2366816539
# Processing https://openalex.org/W2368218525
# Processing https://openalex.org/W2375187415
# Processing https://openalex.org/W2376609871
# Processing https://openalex.org/W2378057080
# Processing https://openalex.org/W2380359989
# Processing https://openalex.org/W2387291285
# Processing https://openalex.org/W2388800308
# Processing https://openalex.org/W2389521723
# Processing https://openalex.org/W2403977165
# Processing https://openalex.org/W2473722593
# Processing https://openalex.org/W2476394513
# Processing https://openalex.org/W2482682982
# Processing https://openalex.org/W2485689150
# Processing https://openalex.org/W2495276003
# Processing https://openalex.org/W2507475885
# Processing https://openalex.org/W2512952691
# Processing https://openalex.org/W2527995213
# Processing https://openalex.org/W2544001857
# Processing https://openalex.org/W2553521091
# Processing https://openalex.org/W2561736289
# Processing https://openalex.org/W2565185528
# Processing https://openalex.org/W2580182246
# Processing https://openalex.org/W2587329652
# Processing https://openalex.org/W2587720673
# Processing https://openalex.org/W2588161629
# Processing https://openalex.org/W2589434942
# Processing https://openalex.org/W2592479289
# Processing https://openalex.org/W2595264819
# Processing https://openalex.org/W2596999048
# Processing https://openalex.org/W2598091349
# Processing https://openalex.org/W2598656573
# Processing https://openalex.org/W2602849344
# Processing https://openalex.org/W2612875108
# Processing https://openalex.org/W2619151633
# Processing https://openalex.org/W2625426831
# Processing https://openalex.org/W2625992765
# Processing https://openalex.org/W2635740930
# Processing https://openalex.org/W2663861583
# Processing https://openalex.org/W267019868
# Processing https://openalex.org/W2716435981
# Processing https://openalex.org/W2741490491
# Processing https://openalex.org/W2756659966
# Processing https://openalex.org/W2761614070
# Processing https://openalex.org/W2766173862
# Processing https://openalex.org/W2767134817
# Processing https://openalex.org/W2767739989
# Processing https://openalex.org/W2772867153
# Processing https://openalex.org/W2773177589
# Processing https://openalex.org/W2773358030
# Processing https://openalex.org/W2780097379
# Processing https://openalex.org/W2789684694
# Processing https://openalex.org/W2794220255
# Processing https://openalex.org/W2801737043
# Processing https://openalex.org/W2804095451
# Processing https://openalex.org/W2804958844
# Processing https://openalex.org/W2806349642
# Processing https://openalex.org/W2807800750
# Processing https://openalex.org/W2811219136
# Processing https://openalex.org/W2883024550
# Processing https://openalex.org/W2887573038
# Processing https://openalex.org/W2889122466
# Processing https://openalex.org/W2890540479
# Processing https://openalex.org/W2890591802
# Processing https://openalex.org/W2890853717
# Processing https://openalex.org/W2891903686
# Processing https://openalex.org/W2895165109
# Processing https://openalex.org/W2896751489
# Processing https://openalex.org/W2897475839
# Processing https://openalex.org/W2900408224
# Processing https://openalex.org/W2902789768
# Processing https://openalex.org/W2906080883
# Processing https://openalex.org/W2908577399
# Processing https://openalex.org/W291004932
# Processing https://openalex.org/W2913916335
# Processing https://openalex.org/W2914094440
# Processing https://openalex.org/W2918831213
# Processing https://openalex.org/W2920476039
# Processing https://openalex.org/W2921069773
# Processing https://openalex.org/W2921143263
# Processing https://openalex.org/W2921237584
# Processing https://openalex.org/W2921712035
# Processing https://openalex.org/W2922039017
# Processing https://openalex.org/W2922209108
# Processing https://openalex.org/W2922684064
# Processing https://openalex.org/W2922736319
# Processing https://openalex.org/W2924600205
# Processing https://openalex.org/W2931489399
# Processing https://openalex.org/W2933369931
# Processing https://openalex.org/W2936910510
# Processing https://openalex.org/W2938378096
# Processing https://openalex.org/W2940947093
# Processing https://openalex.org/W2942948331
# Processing https://openalex.org/W2943104001
# Processing https://openalex.org/W2943421593
# Processing https://openalex.org/W2943543771
# Processing https://openalex.org/W2944091914
# Processing https://openalex.org/W2947666646
# Processing https://openalex.org/W2953817338
# Processing https://openalex.org/W2955018254
# Processing https://openalex.org/W2963918180
# Processing https://openalex.org/W2965558093
# Processing https://openalex.org/W2966414435
# Processing https://openalex.org/W2967279307
# Processing https://openalex.org/W2968697195
# Processing https://openalex.org/W2971359031
# Processing https://openalex.org/W2972798438
# Processing https://openalex.org/W2978816005
# Processing https://openalex.org/W2980728415
# Processing https://openalex.org/W2981344849
# Processing https://openalex.org/W2984996373
# Processing https://openalex.org/W2986629221
# Processing https://openalex.org/W2997562221
# Processing https://openalex.org/W3000604125
# Processing https://openalex.org/W3001385022
# Processing https://openalex.org/W3001811947
# Processing https://openalex.org/W3007051557
# Processing https://openalex.org/W3008379420
# Processing https://openalex.org/W3021741550
# Processing https://openalex.org/W3022704615
# Processing https://openalex.org/W3025499686
# Processing https://openalex.org/W3025676006
# Processing https://openalex.org/W3026679872
# Processing https://openalex.org/W3032637579
# Processing https://openalex.org/W3033501614
# Processing https://openalex.org/W3033668572
# Processing https://openalex.org/W3033929493
# Processing https://openalex.org/W3037216812
# Processing https://openalex.org/W3037705751
# Processing https://openalex.org/W3039577330
# Processing https://openalex.org/W3039606322
# Processing https://openalex.org/W3043515736
# Processing https://openalex.org/W3043938586
# Processing https://openalex.org/W3044383046
# Processing https://openalex.org/W3044954030
# Processing https://openalex.org/W3049173530
# Processing https://openalex.org/W3080387614
# Processing https://openalex.org/W3084113281
# Processing https://openalex.org/W3093752946
# Processing https://openalex.org/W3094369084
# Processing https://openalex.org/W3099122721
# Processing https://openalex.org/W3105823174
# Processing https://openalex.org/W3109347625
# Processing https://openalex.org/W3113905449
# Processing https://openalex.org/W3119775080
# Processing https://openalex.org/W3120292600
# Processing https://openalex.org/W3121144081
# Processing https://openalex.org/W3121217472
# Processing https://openalex.org/W3121421182
# Processing https://openalex.org/W3121518780
# Processing https://openalex.org/W3121545129
# Processing https://openalex.org/W3121626177
# Processing https://openalex.org/W3121694509
# Processing https://openalex.org/W3121808914
# Processing https://openalex.org/W3122167690
# Processing https://openalex.org/W3122768301
# Processing https://openalex.org/W3122884517
# Processing https://openalex.org/W3123195152
# Processing https://openalex.org/W3123202179
# Processing https://openalex.org/W3123505781
# Processing https://openalex.org/W3123563038
# Processing https://openalex.org/W3123638740
# Processing https://openalex.org/W3123816425
# Processing https://openalex.org/W3124044027
# Processing https://openalex.org/W3124226182
# Processing https://openalex.org/W3124279434
# Processing https://openalex.org/W3124358677
# Processing https://openalex.org/W3124369867
# Processing https://openalex.org/W3124481018
# Processing https://openalex.org/W3124527946
# Processing https://openalex.org/W3124550008
# Processing https://openalex.org/W3124621746
# Processing https://openalex.org/W3124992314
# Processing https://openalex.org/W3125052842
# Processing https://openalex.org/W3125112178
# Processing https://openalex.org/W3125155430
# Processing https://openalex.org/W3125318571
# Processing https://openalex.org/W3125330545
# Processing https://openalex.org/W3125359030
# Processing https://openalex.org/W3125406097
# Processing https://openalex.org/W3125643021
# Processing https://openalex.org/W3125844548
# Processing https://openalex.org/W3125856458
# Processing https://openalex.org/W3126032812
# Processing https://openalex.org/W3128702014
# Processing https://openalex.org/W3129579937
# Processing https://openalex.org/W3132136530
# Processing https://openalex.org/W3136260651
# Processing https://openalex.org/W3136420028
# Processing https://openalex.org/W3142916655
# Processing https://openalex.org/W3145594932
# Processing https://openalex.org/W3147268152
# Processing https://openalex.org/W3150419855
# Processing https://openalex.org/W3156722884
# Processing https://openalex.org/W3163153651
# Processing https://openalex.org/W3163537223
# Processing https://openalex.org/W3168728451
# Processing https://openalex.org/W3169577729
# Processing https://openalex.org/W3170592684
# Processing https://openalex.org/W3171039042
# Processing https://openalex.org/W3176622639
# Processing https://openalex.org/W3176921257
# Processing https://openalex.org/W3178385122
# Processing https://openalex.org/W3181553951
# Processing https://openalex.org/W3181973673
# Processing https://openalex.org/W3182550406
# Processing https://openalex.org/W3184422859
# Processing https://openalex.org/W3185155858
# Processing https://openalex.org/W3186457560
# Processing https://openalex.org/W3189747191
# Processing https://openalex.org/W3190097825
# Processing https://openalex.org/W3190102834
# Processing https://openalex.org/W3192903419
# Processing https://openalex.org/W3195123941
# Processing https://openalex.org/W3197901707
# Processing https://openalex.org/W3198616739
# Processing https://openalex.org/W3202153609
# Processing https://openalex.org/W3202616165
# Processing https://openalex.org/W3202722289
# Processing https://openalex.org/W3204672706
# Processing https://openalex.org/W3204735205
# Processing https://openalex.org/W3207067564
# Processing https://openalex.org/W3207371012
# Processing https://openalex.org/W3207400243
# Processing https://openalex.org/W3208534945
# Processing https://openalex.org/W3210465688
# Processing https://openalex.org/W3211027916
# Processing https://openalex.org/W3214804213
# Processing https://openalex.org/W3216038618
# Processing https://openalex.org/W3216509343
# Processing https://openalex.org/W325124896
# Processing https://openalex.org/W37448061
# Processing https://openalex.org/W4200297537
# Processing https://openalex.org/W4205360523
# Processing https://openalex.org/W4205552064
# Processing https://openalex.org/W4205619119
# Processing https://openalex.org/W4205731136
# Processing https://openalex.org/W4206194690
# Processing https://openalex.org/W4210953259
# Processing https://openalex.org/W4211263339
# Processing https://openalex.org/W4212888016
# Processing https://openalex.org/W4220692802
# Processing https://openalex.org/W4220732045
# Processing https://openalex.org/W4225276593
# Processing https://openalex.org/W4226345407
# Processing https://openalex.org/W4230356224
# Processing https://openalex.org/W4230700148
# Processing https://openalex.org/W4230711751
# Processing https://openalex.org/W4232769139
# Processing https://openalex.org/W4238048379
# Processing https://openalex.org/W4241858005
# Processing https://openalex.org/W4247667710
# Processing https://openalex.org/W4252430879
# Processing https://openalex.org/W4252745096
# Processing https://openalex.org/W4252952688
# Processing https://openalex.org/W4281690951
# Processing https://openalex.org/W4282557620
# Processing https://openalex.org/W4283657131
# Processing https://openalex.org/W4283764937
# Processing https://openalex.org/W4285024880
# Processing https://openalex.org/W4285199241
# Processing https://openalex.org/W4285249755
# Processing https://openalex.org/W4285263003
# Processing https://openalex.org/W4285483025
# Processing https://openalex.org/W4286458987
# Processing https://openalex.org/W4289824063
# Processing https://openalex.org/W4293041566
# Processing https://openalex.org/W4293190917
# Processing https://openalex.org/W4293801681
# Processing https://openalex.org/W4295766715
# Processing https://openalex.org/W4296277673
# Processing https://openalex.org/W4300073440
# Processing https://openalex.org/W4300951185
# Processing https://openalex.org/W4304172618
# Processing https://openalex.org/W4307156538
# Processing https://openalex.org/W4307711555
# Processing https://openalex.org/W4307723330
# Processing https://openalex.org/W4308908946
# Processing https://openalex.org/W4312204683
# Processing https://openalex.org/W4312419656
# Processing https://openalex.org/W4312651175
# Processing https://openalex.org/W4312705867
# Processing https://openalex.org/W4312802865
# Processing https://openalex.org/W4312805135
# Processing https://openalex.org/W4312882163
# Processing https://openalex.org/W4320148496
# Processing https://openalex.org/W4322624816
# Processing https://openalex.org/W4324121632
# Processing https://openalex.org/W4327519823
# Processing https://openalex.org/W4361000524
# Processing https://openalex.org/W4361214653
# Processing https://openalex.org/W4361974330
# Processing https://openalex.org/W4361988923
# Processing https://openalex.org/W4362499633
# Processing https://openalex.org/W4362611983
# Processing https://openalex.org/W4364368805
# Processing https://openalex.org/W4366085258
# Processing https://openalex.org/W4367052625
# Processing https://openalex.org/W4367597654
# Processing https://openalex.org/W4377002343
# Processing https://openalex.org/W4377834046
# Processing https://openalex.org/W4381512763
# Processing https://openalex.org/W4381660505
# Processing https://openalex.org/W4381666160
# Processing https://openalex.org/W4381736130
# Processing https://openalex.org/W4382807722
# Processing https://openalex.org/W4383346553
# Processing https://openalex.org/W4384133380
# Processing https://openalex.org/W4385213642
# Processing https://openalex.org/W4385260730
# Processing https://openalex.org/W4385494974
# Processing https://openalex.org/W4385782198
# Processing https://openalex.org/W4386094306
# Processing https://openalex.org/W4386370708
# Processing https://openalex.org/W4386491507
# Processing https://openalex.org/W4386929517
# Processing https://openalex.org/W4387158607
# Processing https://openalex.org/W4387172619
# Processing https://openalex.org/W4387195562
# Processing https://openalex.org/W4387912130
# Processing https://openalex.org/W4388626236
# Processing https://openalex.org/W4388724660
# Processing https://openalex.org/W4388938469
# Processing https://openalex.org/W4390066466
# Processing https://openalex.org/W4390145267
# Processing https://openalex.org/W439017983
# Processing https://openalex.org/W4390487374
# Processing https://openalex.org/W4390693054
# Processing https://openalex.org/W4390870445
# Processing https://openalex.org/W4390920600
# Processing https://openalex.org/W4391308576
# Processing https://openalex.org/W4391619986
# Processing https://openalex.org/W4391772409
# Processing https://openalex.org/W4392135119
# Processing https://openalex.org/W4392341912
# Processing https://openalex.org/W4392865012
# Processing https://openalex.org/W4394017071
# Processing https://openalex.org/W4394797139
# Processing https://openalex.org/W4395463994
# Processing https://openalex.org/W4395466247
# Processing https://openalex.org/W4396530482
# Processing https://openalex.org/W4396596924
# Processing https://openalex.org/W4399290172
# Processing https://openalex.org/W4399323633
# Processing https://openalex.org/W4399529338
# Processing https://openalex.org/W4401067024
# Processing https://openalex.org/W4401171797
# Processing https://openalex.org/W4401242778
# Processing https://openalex.org/W4401327824
# Processing https://openalex.org/W4401845594
# Processing https://openalex.org/W4401871424
# Processing https://openalex.org/W4402018025
# Processing https://openalex.org/W4402066912
# Processing https://openalex.org/W4402314342
# Processing https://openalex.org/W4402546895
# Processing https://openalex.org/W4402923847
# Processing https://openalex.org/W4402986304
# Processing https://openalex.org/W4403370613
# Processing https://openalex.org/W4403660177
# Processing https://openalex.org/W4404002973
# Processing https://openalex.org/W4404109958
# Processing https://openalex.org/W4405654739
# Processing https://openalex.org/W4405920878
# Processing https://openalex.org/W4406103194
# Processing https://openalex.org/W4406151692
# Processing https://openalex.org/W4406632693
# Processing https://openalex.org/W4407152405
# Processing https://openalex.org/W4407463226
# Processing https://openalex.org/W59453117
# Processing https://openalex.org/W623596649
# Processing https://openalex.org/W70509848
# Processing https://openalex.org/W765699370
# Processing https://openalex.org/W85222481
# Processing https://openalex.org/W8680042

# %%
cat_df = pd.DataFrame(cat.items(), columns=['id', 'result'])
cat_df[['rq_cat', 'rq_type']] = cat_df['result'].apply(lambda x: pd.Series(json.loads(x)))
cat_df = cat_df.drop(columns=['result'])
cat_df.to_csv(f'{path}/results/rqtypes_categories_617_withTitle.csv', index=False)

# %%
estimated_costs_df = pd.DataFrame(estimated_costs.items(), columns=['id', 'cost'])
estimated_costs_df.to_csv(f'{path}/results/datatypes_estimated_costs_617_withTitle.csv', index=False)

# %%
print(estimated_costs_df['cost'].sum().round(3), 'Euros')
# Out:
# 2.14 Euros

# %% [markdown]
# # Difference check (Cohen's Kappa)

# %%
df = pd.read_csv(f'{path}/data_abstracts/true_mobility_studies_617_forKGs_cleaned.csv')

data_cat_num = {
    "Panel/Longitudinal Surveys": 1,
    "Administrative/Registry Data": 2, 
    "National Survey Data": 3,
    "Opportunity Atlas": 4,
    "Natural/Experimental Data": 5,
    "Linked Administrative Data": 6,
    "International Panel Data": 7,
    "Rich List Data": 8,
    "University/Institution Data": 9,
    "Pseudo-Panel/Household Budget Survey": 10,
    "Archival/Historical Data": 11,
    "Big Data": 12,
    "No dataset": 13,
    "Others": 14
}

rq_cat_num = {
    "Measurement and Methodological Advances": 1,
    "Empirical Estimates and Determinants": 2,
    "Policy, Institutional, and Geographic Impacts": 3,
    "Intergenerational Wealth Mobility and Inheritance": 4,
    "Demographic Differences in Mobility (Race, Gender, etc.)": 5,
    "Mobility and Non-Income Outcomes (Health, Wellbeing, etc.)": 6,
    "Theoretical and Structural Models": 7,
    "Perceptions of Mobility and Attitudes": 8,
    "Others": 9
}
    
    
    
df['data_cat_num'] = df['data_cat'].replace(data_cat_num).astype(int)
df['rq_cat_num'] = df['rq_cat'].replace(rq_cat_num).astype(int)
# Out:
# /var/folders/xy/r3gq5vtd7bx6qb966l0fhh9h0000gn/T/ipykernel_27202/1720448830.py:34: FutureWarning:
#
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#
# /var/folders/xy/r3gq5vtd7bx6qb966l0fhh9h0000gn/T/ipykernel_27202/1720448830.py:35: FutureWarning:
#
# Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
from sklearn.metrics import cohen_kappa_score
import plotly.graph_objects as go

df2 = pd.read_csv(f'{path}/results/methods_categories_617_withTitle.csv')
print(f"⚠️ For index {df2[df2['method_cat'] == 12].index.values}, its value of {df2[df2['method_cat'] == 12]['method_cat'].values} will be changed to 1. \nGiven its description: {df2[df2['method_cat'] == 12]['method_type'].values}")
df2['method_cat'] = df2['method_cat'].replace({12:1}) 

rater1 = df['category_n1']
rater2 = df2['method_cat']
kappa = cohen_kappa_score(rater1, rater2)

fig = go.Figure()
fig.add_trace(go.Histogram(x=rater1, name='Rater 1', opacity=0.5))
fig.add_trace(go.Histogram(x=rater2, name='Rater 2', opacity=0.3))
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    # paper_bgcolor='rgba(0,0,0,0)',
    showlegend=True,
    title=f'Histogram of Method Categories (Cohen\'s Kappa: {kappa:.2f})',
    xaxis_title='Method Category',
    yaxis_title='Count',
    barmode='overlay',
    bargap=0.1,
    bargroupgap=0.1,
    font=dict(size=16, color='black'),
    font_family="Times New Roman"
)
# Out:
# ⚠️ For index [392], its value of [12] will be changed to 1.
# Given its description: ['Intergenerational Elasticity (IGE) (a regression‐based measure, Category 1) and rank‐rank slope (a rank‐based measure, Category 2)']

# %%
# fig.write_image(f'{path}/results/Paper/img/methods_categories_CohenKapp_{timestamp}.svg')

# %%
df2 = pd.read_csv(f'{path}/results/datatypes_categories_617_withTitle.csv')
unusual = df2[df2['data_cat'] == 0]
print(f"These are unusual categories (IDs: {unusual['id'].values}): \n{unusual} \nWe will take the first values in the description.")

df2.loc[df2['id'] == 537, 'data_cat'] = 1
df2.loc[df2['id'] == 557, 'data_cat'] = 2

rater1 = df['data_cat_num']
rater2 = df2['data_cat']
kappa = cohen_kappa_score(rater1, rater2)

fig = go.Figure()
fig.add_trace(go.Histogram(x=rater1, name='Rater 1', opacity=0.5))
fig.add_trace(go.Histogram(x=rater2, name='Rater 2', opacity=0.3))
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    # paper_bgcolor='rgba(0,0,0,0)',
    showlegend=False,
    title=f'Histogram of DataType Categories (Cohen\'s Kappa: {kappa:.2f})',
    xaxis_title='DataType Category',
    yaxis_title='Count',
    barmode='overlay',
    bargap=0.1,
    bargroupgap=0.1,
    font=dict(size=16, color='black'),
    font_family="Times New Roman"
)
# Out:
# These are unusual categories (IDs: [537 557]):
#       id  data_cat                                          data_type
# 537  537         0  The paper uses two types of datasets. First, i...
# 557  557         0  2: rich administrative data; 1: Panel Study of...
# We will take the first values in the description.

# %%
# fig.write_image(f'{path}/results/Paper/img/datatype_categories_CohenKapp_{timestamp}.svg')

# %%
rater1 = df['rq_cat_num']
rater2 = pd.read_csv(f'{path}/results/rqtypes_categories_617_withTitle.csv')['rq_cat']
kappa = cohen_kappa_score(rater1, rater2)

fig = go.Figure()
fig.add_trace(go.Histogram(x=rater1, name='Rater 1', opacity=0.5))
fig.add_trace(go.Histogram(x=rater2, name='Rater 2', opacity=0.3))
fig.update_layout(
    plot_bgcolor='rgba(0,0,0,0)',
    # paper_bgcolor='rgba(0,0,0,0)',
    showlegend=False,
    title=f'Histogram of RQType Categories (Cohen\'s Kappa: {kappa:.2f})',
    xaxis_title='RQType Category',
    yaxis_title='Count',
    barmode='overlay',
    bargap=0.1,
    bargroupgap=0.1,
    font=dict(size=16, color='black'),
    font_family="Times New Roman"
)

# %%
# fig.write_image(f'{path}/results/Paper/img/rqtype_categories_CohenKapp_{timestamp}.svg')

# %% [markdown]
# `🫨 As expected, RQ cat is not very reliable`

# %%
m1 = pd.read_csv(f'{path}/results/methods_categories_617_withTitle.csv').rename(columns={
    'method_cat': 'method_cat_title_num',
    'method_type': 'method_type_title'
})

m1['method_cat_title_num'] = m1['method_cat_title_num'].replace({12:1})

m2 = pd.read_csv(f'{path}/results/datatypes_categories_617_withTitle.csv').rename(columns={
    'data_cat': 'data_cat_title_num',
    'data_type': 'data_type_title'
})
m2.loc[m2['id'] == 537, 'data_cat_title_num'] = 1
m2.loc[m2['id'] == 557, 'data_cat_title_num'] = 2

m3 = pd.read_csv(f'{path}/results/rqtypes_categories_617_withTitle.csv').rename(columns={
    'rq_cat': 'rq_cat_title_num',
    'rq_type': 'rq_type_title'
})

df = df.drop(columns=['id.1', 'index'])
df = pd.concat([df, m1.loc[:, m1.columns != 'id'],
                    m2.loc[:, m2.columns != 'id'],
                    m3.loc[:, m3.columns != 'id']], axis=1)

# %% [markdown]
# # Adding the newly assigned version of the properties

# %%
new_method = {1: 'Regression‐based Measures', 2: 'Rank‐based Measures', 
             3: 'Transition Matrix / Probability Measures', 4: 'Absolute Mobility Measures',
             5: 'Multigenerational Measures', 6: 'Decomposition / Structural Approaches',
             7: 'Non‐parametric Approaches', 8: 'Others'}

new_rq = {1: 'Measurement and Methodological Advances', 2: 'Empirical Estimates and Determinants', 
          3: 'Policy, Institutional, and Geographic Impacts', 4: 'Intergenerational Wealth Mobility and Inheritance', 
          5: 'Demographic Differences in Mobility (Race, Gender, etc.)', 6: 'Mobility and Non-Income Outcomes (Health, Wellbeing, etc.)', 
          7: 'Theoretical and Structural Models', 8: 'Perceptions of Mobility and Attitudes', 9: 'Others'}


new_data = {1: 'Panel/Longitudinal Surveys', 2: 'Administrative/Registry Data',
            3: 'National Survey Data', 4: 'Opportunity Atlas',
            5: 'Natural/Experimental Data', 6: 'Linked Administrative Data',
            7: 'International Panel Data', 8: 'Rich List Data',
            9: 'University/Institution Data', 10: 'Pseudo-Panel/Household Budget Survey',
            11: 'Archival/Historical Data', 12: 'Big Data',
            13: 'No dataset', 14: 'Others'}


df['method_cat_title'] = df['method_cat_title_num'].astype(int).replace(new_method)
df['rq_cat_title'] = df['rq_cat_title_num'].astype(int).replace(new_rq)
df['data_cat_title'] = df['data_cat_title_num'].astype(int).replace(new_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 21
#       6 new_rq = {1: 'Measurement and Methodological Advances', 2: 'Empirical Estimates and Determinants',
#       7           3: 'Policy, Institutional, and Geographic Impacts', 4: 'Intergenerational Wealth Mobility and Inheritance',
#       8           5: 'Demographic Differences in Mobility (Race, Gender, etc.)', 6: 'Mobility and Non-Income Outcomes (Health, Wellbeing, etc.)',
#       9           7: 'Theoretical and Structural Models', 8: 'Perceptions of Mobility and Attitudes', 9: 'Others'}
#      12 new_data = {1: 'Panel/Longitudinal Surveys', 2: 'Administrative/Registry Data',
#      13             3: 'National Survey Data', 4: 'Opportunity Atlas',
#      14             5: 'Natural/Experimental Data', 6: 'Linked Administrative Data',
#    (...)
#      17             11: 'Archival/Historical Data', 12: 'Big Data',
#      18             13: 'No dataset', 14: 'Others'}
# ---> 21 df['method_cat_title'] = df['method_cat_title_num'].astype(int).replace(new_method)
#      22 df['rq_cat_title'] = df['rq_cat_title_num'].astype(int).replace(new_rq)
#      23 df['data_cat_title'] = df['data_cat_title_num'].astype(int).replace(new_data)
#
# NameError: name 'df' is not defined

# %%
df['method_cat_title'].unique(), df['data_cat_title'].unique()
# Out:
# (array(['Absolute Mobility Measures', 'Regression‐based Measures',
#         'Transition Matrix / Probability Measures', 'Others',
#         'Rank‐based Measures', 'Decomposition / Structural Approaches',
#         'Multigenerational Measures', 'Non‐parametric Approaches'],
#        dtype=object),
#  array(['Administrative/Registry Data', 'No dataset',
#         'Panel/Longitudinal Surveys', 'Others',
#         'Linked Administrative Data', 'National Survey Data', 'Big Data',
#         'Natural/Experimental Data', 'Opportunity Atlas',
#         'International Panel Data', 'Pseudo-Panel/Household Budget Survey',
#         'Archival/Historical Data', 'University/Institution Data'],
#        dtype=object))

# %%
# df.to_csv(f'{path}/data_abstracts/true_mobility_studies_617_forKGs_cleaned_withTitle.csv', index=False)

# %%
df = pd.read_csv(f'{path}/data_abstracts/true_mobility_studies_617_forKGs_cleaned_withTitle.csv')

# %%
df2 = pd.read_csv(f'{path}/results/citations_between_ids_g2_exists(year)_0605_1617.csv')
len(df2)
# Out:
# 2586

# %%
df2.head()
# Out:
#                             from_id                             to_id  weights
# 0  https://openalex.org/W2900408224  https://openalex.org/W2210747677        1
# 1  https://openalex.org/W2914094440  https://openalex.org/W2210747677        1
# 2  https://openalex.org/W3039606322  https://openalex.org/W2210747677        1
# 3  https://openalex.org/W3128702014  https://openalex.org/W2210747677        1
# 4  https://openalex.org/W4296277673  https://openalex.org/W2210747677        1

# %%
unique_ids = set(df2['from_id']).union(set(df2['to_id']))
len(unique_ids)
# Out:
# 469

# %%
df.columns
# Out:
# Index(['id', 'title', 'year', 'doi', 'landing_page', 'abstract_inverted_index',
#        'language', 'is_oa', 'oa_status', 'oa_link', 'abstract', 'abstract_sm',
#        'authors_sm', 'domain', 'sort_gpt_1', 'sort_gpt_2', 'sort_gpt4o_1',
#        'sort_gpt4o_2', 'cited_by', 'len_cited_by', 'ref_count',
#        'cited_by_count', 'Q1', 'Q1_1', 'Q2', 'Q2_1', 'Q2_2', 'Q3', 'Q4', 'abs',
#        'category_n1', 'measure', 'specified', 'relevant', 'category_n2',
#        'measure_1', 'measure_2', 'category_3', 'file', 'Question1',
#        'Question2', 'rq_cat', 'RQ', 'data_cat', 'data_type', 'type',
#        'category_1', 'category_2', 'author_raw_names',
#        'author_raw_affiliations', 'topic_display_names', 'topic_scores',
#        'field_display_names', 'subfield_display_names', 'data_cat_num',
#        'rq_cat_num', 'method_cat_title_num', 'method_type_title',
#        'data_cat_title_num', 'data_type_title', 'rq_cat_title_num',
#        'rq_type_title', 'method_cat_title', 'rq_cat_title', 'data_cat_title'],
#       dtype='object')

# %%
# Instead of creating new nodes for each edge, we will merge the existing nodes with the new titles
# This approach is okay since we are not taking into account the second category of the method for the new ones.
df2 = df2.merge(
    df[['id', 'data_cat_title', 'method_cat_title', 'rq_cat_title', 'year', 'category_1', 'data_cat', 'rq_cat']],
    left_on='from_id', right_on='id', how='left'
).rename(columns={
    'data_cat_title': 'from_data_cat_title',
    'method_cat_title': 'from_method_cat_title',
    'rq_cat_title': 'from_rq_cat_title',
    'year': 'from_year',
    'category_1': 'from_method_cat',
    'data_cat': 'from_data_cat',
    'rq_cat': 'from_rq_cat'
}).drop(columns='id')

df2 = df2.merge(
    df[['id', 'data_cat_title', 'method_cat_title', 'rq_cat_title', 'year', 'category_1', 'data_cat', 'rq_cat']],
    left_on='to_id', right_on='id', how='left'
).rename(columns={
    'data_cat_title': 'to_data_cat_title',
    'method_cat_title': 'to_method_cat_title',
    'rq_cat_title': 'to_rq_cat_title',
    'year': 'to_year',
    'category_1': 'to_method_cat',
    'data_cat': 'to_data_cat',
    'rq_cat': 'to_rq_cat'
}).drop(columns='id')

len(df2)
# Out:
# 2586

# %%
df2.head()
# Out:
#                             from_id                             to_id  \
# 0  https://openalex.org/W2900408224  https://openalex.org/W2210747677
# 1  https://openalex.org/W2914094440  https://openalex.org/W2210747677
# 2  https://openalex.org/W3039606322  https://openalex.org/W2210747677
# 3  https://openalex.org/W3128702014  https://openalex.org/W2210747677
# 4  https://openalex.org/W4296277673  https://openalex.org/W2210747677
#
#    weights          from_data_cat_title      from_method_cat_title  \
# 0        1   Linked Administrative Data  Regression‐based Measures
# 1        1  University/Institution Data                     Others
# 2        1         National Survey Data  Regression‐based Measures
# 3        1   Panel/Longitudinal Surveys                     Others
# 4        1   Panel/Longitudinal Surveys  Regression‐based Measures
#
#                                    from_rq_cat_title  from_year  \
# 0               Empirical Estimates and Determinants       2018
# 1               Empirical Estimates and Determinants       2019
# 2  Intergenerational Wealth Mobility and Inheritance       2020
# 3            Measurement and Methodological Advances       2021
# 4               Empirical Estimates and Determinants       2022
#
#              from_method_cat                from_data_cat  \
# 0  Regression‐based Measures                   No dataset
# 1                     Others  University/Institution Data
# 2  Regression‐based Measures         National Survey Data
# 3                     Others   Panel/Longitudinal Surveys
# 4  Regression‐based Measures   Panel/Longitudinal Surveys
#
#                                          from_rq_cat  ...  \
# 0               Empirical Estimates and Determinants  ...
# 1               Empirical Estimates and Determinants  ...
# 2  Intergenerational Wealth Mobility and Inheritance  ...
# 3  Intergenerational Wealth Mobility and Inheritance  ...
# 4               Empirical Estimates and Determinants  ...
#
#              from_method_cat                from_data_cat  \
# 0  Regression‐based Measures                   No dataset
# 1                     Others  University/Institution Data
# 2  Regression‐based Measures         National Survey Data
# 3                     Others   Panel/Longitudinal Surveys
# 4  Regression‐based Measures   Panel/Longitudinal Surveys
#
#                                          from_rq_cat  \
# 0               Empirical Estimates and Determinants
# 1               Empirical Estimates and Determinants
# 2  Intergenerational Wealth Mobility and Inheritance
# 3  Intergenerational Wealth Mobility and Inheritance
# 4               Empirical Estimates and Determinants
#
#             to_data_cat_title        to_method_cat_title  \
# 0  Panel/Longitudinal Surveys  Regression‐based Measures
# 1  Panel/Longitudinal Surveys  Regression‐based Measures
# 2  Panel/Longitudinal Surveys  Regression‐based Measures
# 3  Panel/Longitudinal Surveys  Regression‐based Measures
# 4  Panel/Longitudinal Surveys  Regression‐based Measures
#
#                         to_rq_cat_title to_year              to_method_cat  \
# 0  Empirical Estimates and Determinants    2017  Regression‐based Measures
# 1  Empirical Estimates and Determinants    2017  Regression‐based Measures
# 2  Empirical Estimates and Determinants    2017  Regression‐based Measures
# 3  Empirical Estimates and Determinants    2017  Regression‐based Measures
# 4  Empirical Estimates and Determinants    2017  Regression‐based Measures
#
#                   to_data_cat                             to_rq_cat
# 0  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 1  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 2  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 3  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 4  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
#
# [5 rows x 28 columns]

# %%
# df2.to_csv(f'{path}/results/citation_networks_617_withTitle_full.csv', index=False)

# %%
sets = ['method', 'data', 'rq']
for set in sets:
   grouped = df2.groupby([f'from_{set}_cat_title', f'to_{set}_cat_title']).size().reset_index(name='weight').sort_values(by='weight', ascending=False)
   grouped.to_csv(f'{path}/results/citation_network_{set}_withTitle_{timestamp}.csv', index=False)

# %%
# grouped = df2.groupby(['from_year', 'to_year']).size().reset_index(name='weights').sort_values(by='weights', ascending=False)
# grouped.to_csv(f'{path}/results/citation_network_years_{timestamp}.csv', index=False)

grouped = (
    df2.dropna(subset=['from_year', 'to_year'])  # eliminate bad merges
       .groupby(['from_year', 'to_year'])['weights']  # use original Neo4j weight
       .sum()
       .reset_index()
       .sort_values(by='weights', ascending=False)
)

# %%
grouped
# Out:
#      from_year  to_year  weights
# 365       2024     2014       47
# 316       2022     2014       46
# 247       2019     2014       42
# 292       2021     2014       41
# 370       2024     2019       38
# ..         ...      ...      ...
# 191       2017     1990        1
# 192       2017     1992        1
# 1         1981     1979        1
# 195       2017     2003        1
# 193       2017     1999        1
#
# [387 rows x 3 columns]

# %%
g1 = pd.read_csv(f"{path}/results/citations_between_years_g2_0605_1616.csv")
g1
# Out:
#      from_year  to_year  weights
# 0         2024     2014       47
# 1         2022     2014       46
# 2         2019     2014       42
# 3         2021     2014       41
# 4         2024     2019       38
# ..         ...      ...      ...
# 382       2022     1990        1
# 383       2023     1990        1
# 384       2020     1997        1
# 385       2009     1999        1
# 386       2017     1999        1
#
# [387 rows x 3 columns]

# %%
merged = pd.merge(g1, grouped, on=['from_year', 'to_year'], how='outer').fillna(0)
merged['diff'] = merged['weights_x'] - merged['weights_y']

# Show mismatches
merged[merged['diff'] != 0]
# Out:
# Empty DataFrame
# Columns: [from_year, to_year, weights_x, weights_y, diff]
# Index: []

# %% [markdown]
# ## Extracting csv's for viz

# %%
df = pd.read_csv(f'{path}/data_abstracts/true_mobility_studies_617_forKGs_cleaned_withTitle.csv')
df.columns
# Out:
# Index(['id', 'title', 'year', 'doi', 'landing_page', 'abstract_inverted_index',
#        'language', 'is_oa', 'oa_status', 'oa_link', 'abstract', 'abstract_sm',
#        'authors_sm', 'domain', 'sort_gpt_1', 'sort_gpt_2', 'sort_gpt4o_1',
#        'sort_gpt4o_2', 'cited_by', 'len_cited_by', 'ref_count',
#        'cited_by_count', 'Q1', 'Q1_1', 'Q2', 'Q2_1', 'Q2_2', 'Q3', 'Q4', 'abs',
#        'category_n1', 'measure', 'specified', 'relevant', 'category_n2',
#        'measure_1', 'measure_2', 'category_3', 'file', 'Question1',
#        'Question2', 'rq_cat', 'RQ', 'data_cat', 'data_type', 'type',
#        'category_1', 'category_2', 'author_raw_names',
#        'author_raw_affiliations', 'topic_display_names', 'topic_scores',
#        'field_display_names', 'subfield_display_names', 'data_cat_num',
#        'rq_cat_num', 'method_cat_title_num', 'method_type_title',
#        'data_cat_title_num', 'data_type_title', 'rq_cat_title_num',
#        'rq_type_title', 'method_cat_title', 'rq_cat_title', 'data_cat_title'],
#       dtype='object')

# %%
# swamp_cat1 = df.groupby(['year', 'method_cat_title']).size().reset_index(name='count').sort_values(by='year', ascending=True)
# swamp_cat1.to_csv(f'{path}/results/methods_title_over_years617.csv', index=False)
swamp_cat1 = df.groupby(['year', 'category_1']).size().reset_index(name='count').sort_values(by='year', ascending=True)

# %%
import plotly.express as px

fig = px.bar(swamp_cat1, 
             x='year', 
             y='count', 
            #  color='method_cat_title', 
            color = 'category_1',
             title='Method Categories Over Years (617 Studies)',
             labels={'year': 'Year', 'count': 'Count'},
             color_discrete_sequence=px.colors.qualitative.Pastel)

fig.show()

# %%
import plotly.express as px

# For Methods (Categories)
color_palette = {"Regression‐based Measures": "#B5DBA5",
                 "Rank‐based Measures": "#F4A988",
                 "Transition Matrix / Probability Measures": "#CB7729",
                 "Absolute Mobility Measures": "#C04E3F",
                 "Multigenerational Measures": "#FFC3C2",
                 "Decomposition / Structural Approaches": "#339999",
                 "Non‐parametric Approaches": "#005F56",
                 "Others": "#F4E1A1"}

data_sub = swamp_cat1[swamp_cat1['year'] >= 2010].copy()
data_sub['relative_count'] = data_sub.groupby('year')['count'].transform(lambda x: x / x.sum())

fig = px.bar(data_sub, 
             x='year', 
             y='relative_count', 
            #  color='method_cat_title',
            color = 'category_1',
            #  title='Method Categories Over Years (617 Studies)',
             labels={'year': 'Year', 'count': 'Count'},
             color_discrete_map=color_palette)
fig.update_layout(
    plot_bgcolor='rgba(255,255,255,0)',
    paper_bgcolor='rgba(255,255,255,0)',
    xaxis_title='Year',
    yaxis_title='Relative Frequency (per year)',
    # legend_title_text='Method Category',
    showlegend=False,
    font=dict(size=16, color='black'),
    font_family="Times New Roman",
    barmode='stack'
)

fig.show()

# %%
# Compute 3-year moving average of absolute frequencies (count) for each method_cat_title
# data_sub_sorted = data_sub.sort_values(['method_cat_title', 'year'])
data_sub_sorted = swamp_cat1.sort_values(['category_1', 'year'])
data_sub_sorted['ma_3yr_abs'] = (
    data_sub_sorted
    # .groupby('method_cat_title')['count']
    .groupby('category_1')['count']
    .transform(lambda x: x.rolling(window=3, min_periods=1, center=True).mean())
)

data_sub_sorted = data_sub_sorted[data_sub_sorted['year'] >= 2010].copy()  # Filter for years >= 2010
# For each year, compute the sum of moving averages across all categories
year_ma_sum = data_sub_sorted.groupby('year')['ma_3yr_abs'].transform('sum')

# Convert to relative frequency per year
data_sub_sorted['ma_3yr_rel'] = data_sub_sorted['ma_3yr_abs'] / year_ma_sum * 100

fig = px.bar(
    data_sub_sorted,
    x='year',
    y='ma_3yr_rel',
    # color='method_cat_title',
    color='category_1',
    labels={'year': 'Year', 'ma_3yr_rel': '3-Year Moving Avg. %'},
    color_discrete_map=color_palette
)
fig.update_layout(
    plot_bgcolor='rgba(255,255,255,0)',
    xaxis_title='Year',
    yaxis_title='3-Year Moving Avg. % (per year)',
    showlegend=False,
    font=dict(size=16, color='black'),
    font_family="Times New Roman",
    barmode='stack'
)
fig.show()

# %%
# fig.write_image(f'{path}/results/Paper/img/methods_title_between2010-25_617_rollingavg.svg')

# %%
data = pd.read_csv(f'{path}/results/citation_networks_617_withTitle_full.csv')
data.head()
# Out:
#                             from_id                             to_id  \
# 0  https://openalex.org/W2900408224  https://openalex.org/W2210747677
# 1  https://openalex.org/W2914094440  https://openalex.org/W2210747677
# 2  https://openalex.org/W3039606322  https://openalex.org/W2210747677
# 3  https://openalex.org/W3128702014  https://openalex.org/W2210747677
# 4  https://openalex.org/W4296277673  https://openalex.org/W2210747677
#
#    weights          from_data_cat_title      from_method_cat_title  \
# 0        1   Linked Administrative Data  Regression‐based Measures
# 1        1  University/Institution Data                     Others
# 2        1         National Survey Data  Regression‐based Measures
# 3        1   Panel/Longitudinal Surveys                     Others
# 4        1   Panel/Longitudinal Surveys  Regression‐based Measures
#
#                                    from_rq_cat_title  from_year  \
# 0               Empirical Estimates and Determinants       2018
# 1               Empirical Estimates and Determinants       2019
# 2  Intergenerational Wealth Mobility and Inheritance       2020
# 3            Measurement and Methodological Advances       2021
# 4               Empirical Estimates and Determinants       2022
#
#              from_method_cat                from_data_cat  \
# 0  Regression‐based Measures                   No dataset
# 1                     Others  University/Institution Data
# 2  Regression‐based Measures         National Survey Data
# 3                     Others   Panel/Longitudinal Surveys
# 4  Regression‐based Measures   Panel/Longitudinal Surveys
#
#                                          from_rq_cat  ...  \
# 0               Empirical Estimates and Determinants  ...
# 1               Empirical Estimates and Determinants  ...
# 2  Intergenerational Wealth Mobility and Inheritance  ...
# 3  Intergenerational Wealth Mobility and Inheritance  ...
# 4               Empirical Estimates and Determinants  ...
#
#            from_method_cat.1              from_data_cat.1  \
# 0  Regression‐based Measures                   No dataset
# 1                     Others  University/Institution Data
# 2  Regression‐based Measures         National Survey Data
# 3                     Others   Panel/Longitudinal Surveys
# 4  Regression‐based Measures   Panel/Longitudinal Surveys
#
#                                        from_rq_cat.1  \
# 0               Empirical Estimates and Determinants
# 1               Empirical Estimates and Determinants
# 2  Intergenerational Wealth Mobility and Inheritance
# 3  Intergenerational Wealth Mobility and Inheritance
# 4               Empirical Estimates and Determinants
#
#           to_data_cat_title.1      to_method_cat_title.1  \
# 0  Panel/Longitudinal Surveys  Regression‐based Measures
# 1  Panel/Longitudinal Surveys  Regression‐based Measures
# 2  Panel/Longitudinal Surveys  Regression‐based Measures
# 3  Panel/Longitudinal Surveys  Regression‐based Measures
# 4  Panel/Longitudinal Surveys  Regression‐based Measures
#
#                       to_rq_cat_title.1 to_year.1              to_method_cat  \
# 0  Empirical Estimates and Determinants      2017  Regression‐based Measures
# 1  Empirical Estimates and Determinants      2017  Regression‐based Measures
# 2  Empirical Estimates and Determinants      2017  Regression‐based Measures
# 3  Empirical Estimates and Determinants      2017  Regression‐based Measures
# 4  Empirical Estimates and Determinants      2017  Regression‐based Measures
#
#                   to_data_cat                             to_rq_cat
# 0  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 1  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 2  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 3  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 4  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
#
# [5 rows x 28 columns]

# %%
data_sub2 = data.groupby(['from_year', 'to_year', 'from_method_cat', 'to_method_cat']).size().reset_index(name='weights').sort_values(by='weights', ascending=False)
data_sub2
# Out:
#       from_year  to_year            from_method_cat  \
# 456        2018     2014  Regression‐based Measures
# 1053       2024     2014  Regression‐based Measures
# 542        2019     2014  Regression‐based Measures
# 532        2019     2013  Regression‐based Measures
# 450        2018     2013  Regression‐based Measures
# ...         ...      ...                        ...
# 488        2019     2002                     Others
# 490        2019     2003  Non‐parametric Approaches
# 492        2019     2003  Regression‐based Measures
# 494        2019     2005  Non‐parametric Approaches
# 1160       2025     2024  Regression‐based Measures
#
#                                  to_method_cat  weights
# 456                        Rank‐based Measures       22
# 1053                       Rank‐based Measures       19
# 542                        Rank‐based Measures       16
# 532                  Regression‐based Measures       14
# 450                  Regression‐based Measures       13
# ...                                        ...      ...
# 488                  Regression‐based Measures        1
# 490                  Regression‐based Measures        1
# 492   Transition Matrix / Probability Measures        1
# 494                  Regression‐based Measures        1
# 1160                 Regression‐based Measures        1
#
# [1161 rows x 5 columns]

# %%
# Use 'cited' or 'citing'
invest = 'from' # or 'to'
most_cited = data_sub2.groupby([f'to_year', f'{invest}_method_cat'], group_keys=False).agg({'weights': 'sum'}).reset_index()
most_cited['percentage'] = most_cited.groupby(f'to_year')['weights'].transform(lambda x: x / x.sum())
most_cited = most_cited.groupby(f'to_year').apply(lambda x: x.nlargest(3, 'weights')).reset_index(drop=True)
most_cited
most_cited.to_csv(f'{path}/results/citation_networks_617_most_cited_by_{invest}_cat_to_year.csv', index=False)
# Out:
# /var/folders/xy/r3gq5vtd7bx6qb966l0fhh9h0000gn/T/ipykernel_62653/1065919578.py:5: DeprecationWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.

# %%
# # Create a mapping of (from_val, to_val) pairs with their associated weight, repeated per each row
# from_to_weights = data[
#     ['from_method_cat_title', 'to_method_cat_title',
#      'from_data_cat_title', 'to_data_cat_title',
#      'from_rq_cat_title', 'to_rq_cat_title', 'weights']
# ]

# # Now, reshape each pair (from, to) to long format with weight preserved
# pairs = []
# for f_col, t_col in [('from_method_cat_title', 'to_method_cat_title'),
#                      ('from_data_cat_title', 'to_data_cat_title'),
#                      ('from_rq_cat_title', 'to_rq_cat_title')]:
#     temp_df = data[[f_col, t_col, 'weights']].copy()
#     temp_df.columns = ['from_val', 'to_val', 'weight']
#     pairs.append(temp_df)

# # Combine all types into one long dataframe and aggregate
# long_weighted_df = pd.concat(pairs, ignore_index=True)

# # Group by (from_val, to_val) and sum the weights
# aggregated_df = long_weighted_df.groupby(['from_val', 'to_val'], as_index=False)['weight'].sum()
# aggregated_df
# Out:
#                                      from_val  \
# 0                  Absolute Mobility Measures
# 1                  Absolute Mobility Measures
# 2                  Absolute Mobility Measures
# 3                  Absolute Mobility Measures
# 4                  Absolute Mobility Measures
# ..                                        ...
# 195  Transition Matrix / Probability Measures
# 196  Transition Matrix / Probability Measures
# 197               University/Institution Data
# 198               University/Institution Data
# 199               University/Institution Data
#
#                                        to_val  weight
# 0                  Absolute Mobility Measures      26
# 1       Decomposition / Structural Approaches       7
# 2                  Multigenerational Measures       1
# 3                   Non‐parametric Approaches       1
# 4                                      Others       4
# ..                                        ...     ...
# 195                 Regression‐based Measures      85
# 196  Transition Matrix / Probability Measures      12
# 197                Linked Administrative Data       2
# 198                                No dataset       5
# 199                Panel/Longitudinal Surveys       7
#
# [200 rows x 3 columns]

# %% [markdown]
# # also about the citing papers' methods over time?

# %%
df = pd.read_csv(f'{path}/data_abstracts/true_mobility_studies_617_forKGs_cleaned_withTitle.csv')
df.columns
# Out:
# Index(['id', 'title', 'year', 'doi', 'landing_page', 'abstract_inverted_index',
#        'language', 'is_oa', 'oa_status', 'oa_link', 'abstract', 'abstract_sm',
#        'authors_sm', 'domain', 'sort_gpt_1', 'sort_gpt_2', 'sort_gpt4o_1',
#        'sort_gpt4o_2', 'cited_by', 'len_cited_by', 'ref_count',
#        'cited_by_count', 'Q1', 'Q1_1', 'Q2', 'Q2_1', 'Q2_2', 'Q3', 'Q4', 'abs',
#        'category_n1', 'measure', 'specified', 'relevant', 'category_n2',
#        'measure_1', 'measure_2', 'category_3', 'file', 'Question1',
#        'Question2', 'rq_cat', 'RQ', 'data_cat', 'data_type', 'type',
#        'category_1', 'category_2', 'author_raw_names',
#        'author_raw_affiliations', 'topic_display_names', 'topic_scores',
#        'field_display_names', 'subfield_display_names', 'data_cat_num',
#        'rq_cat_num', 'method_cat_title_num', 'method_type_title',
#        'data_cat_title_num', 'data_type_title', 'rq_cat_title_num',
#        'rq_type_title', 'method_cat_title', 'rq_cat_title', 'data_cat_title'],
#       dtype='object')

# %%
df[['Question1', 'Question2']].value_counts()
# Out:
# Question1  Question2
# Yes        Yes          617
# Name: count, dtype: int64

# %%
# import logging

# cat = {}
# estimated_costs = {}

# for i, row in df.iterrows():
# # for i, row in df[~df.index.isin(cat.keys())].iterrows():  # Only process rows without those already in 'cat'
#     abs = row['abs'].strip()
#     abs_clean = clean_abs(abs)
#     measure = row['method_cat_title']
#     print(f'Processing {row.id}')
#     start_time = time.time()
#     completion = openai_client.beta.chat.completions.parse(
#                 model= gpt_model,
#                 messages=[
#                     { 
#                     "role": "assistant",
#                     "content": "You are a research assistant in the Social Sciences domain. I, the researcher, have an abstract of a paper that studied inter/multi generational wealth/income/earning mobility."
                    
#                     },
#                     {
#                         "role": "user", 
#                         "content":f"""
#                                 ```Title: {row['title']}
                                                        
#                                 ```Abstracts
#                                 {abs_clean}
#                                 ```
#                                 Based on the ```Title and the ```Abstracts above, you recognized that this paper used {measure}.
#                                 Does this paper use this measure in the following way?
#                                 1. It used it alone to estimate the intergenerational wealth/income/earning mobility.
#                                 2. It used it to estimate something else
#                                 2. It used it in combination with other measures, and the paper specifies which measures. The name of the measures are: [list of measures]. Return None if the paper does not specify the name of the other measures.
#                                 2-1. Which measure(s) does it prefer? If you cannot learn from the abstract, return None.
#                                 3. Does it
                                
#                                 """
#                     }
#                 ],
#                 response_format=,
#             )
#     results = completion.choices[0].message.content
#     tokens_prompt = completion.usage.prompt_tokens
#     tokens_completion = completion.usage.completion_tokens
#     cost = estimate_cost(tokens_prompt, tokens_completion, model=gpt_model)
#     estimated_costs[i] = cost
#     cat[i] = results   
        
# logging.info('✅ Done! The process time is:', time.time()-start_time)
