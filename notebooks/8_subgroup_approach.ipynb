# %%
import pandas as pd
import numpy as np
import os
from datetime import date
today = date.today()
path = os.path.dirname(os.getcwd())
print(f'📂 Current working directory: {path}')
print(f'💚 Today is {today}')
# Out:
# 📂 Current working directory: /Users/serenekim/Desktop/PhD/meta-wealth_mobility
# 💚 Today is 2025-08-19

# %%
# For graph plotting
import sys, pathlib
sys.path.append(str(pathlib.Path.cwd().parent))
import scripts.graph as gr

# %% [markdown]
# # Neo4j Implementation of the Graph API

# %% [markdown]
# ## Data Prep

# %%
# Load your CSV
df = pd.read_csv(f'{path}/data_abstracts/true_mobility_studies_617_forKGs.csv')
df.columns
# Out:
# Index(['id', 'title', 'year', 'doi', 'landing_page', 'abstract_inverted_index',
#        'language', 'is_oa', 'oa_status', 'oa_link', 'abstract', 'abstract_sm',
#        'authors_sm', 'domain', 'sort_gpt_1', 'sort_gpt_2', 'sort_gpt4o_1',
#        'sort_gpt4o_2', 'cited_by', 'len_cited_by', 'ref_count',
#        'cited_by_count', 'Q1', 'Q1_1', 'Q2', 'Q2_1', 'Q2_2', 'Q3', 'Q4', 'abs',
#        'index', 'category_n1', 'measure', 'specified', 'relevant',
#        'category_n2', 'measure_1', 'measure_2', 'category_3', 'file', 'id.1',
#        'Question1', 'Question2', 'rq_cat', 'RQ', 'data_cat', 'data_type',
#        'type', 'category_1', 'category_2', 'author_raw_names',
#        'author_raw_affiliations', 'topic_display_names', 'topic_scores',
#        'field_display_names', 'subfield_display_names'],
#       dtype='object')

# %%
df[df['data_cat']==0][['data_cat', 'data_type']].values # This shouldn't be 0!
# Out:
# array([[0,
#         'European Union Statistics on Income and Living Conditions survey: 3; European Community Household Panel: 7']],
#       dtype=object)

# %%
df['data_cat'] = df['data_cat'].replace({0: 3})
df[df['data_cat'] == 0][['data_cat', 'data_type']].values
# Out:
# array([], shape=(0, 2), dtype=object)

# %%
new_rq = {1: 'Measurement and Methodological Advances', 2: 'Empirical Estimates and Determinants', 
          3: 'Policy, Institutional, and Geographic Impacts', 4: 'Intergenerational Wealth Mobility and Inheritance', 
          5: 'Demographic Differences in Mobility (Race, Gender, etc.)', 6: 'Mobility and Non-Income Outcomes (Health, Wellbeing, etc.)', 
          7: 'Theoretical and Structural Models', 8: 'Perceptions of Mobility and Attitudes', 9: 'Others'}


new_data = {1: 'Panel/Longitudinal Surveys', 2: 'Administrative/Registry Data',
            3: 'National Survey Data', 4: 'Opportunity Atlas',
            5: 'Natural/Experimental Data', 6: 'Linked Administrative Data',
            7: 'International Panel Data', 8: 'Rich List Data',
            9: 'University/Institution Data', 10: 'Pseudo-Panel/Household Budget Survey',
            11: 'Archival/Historical Data', 12: 'Big Data',
            13: 'No dataset', 14: 'Others'}

df['rq_cat'] = df['rq_cat'].replace(new_rq)
df['data_cat'] = df['data_cat'].replace(new_data)
df['rq_cat'] = df['rq_cat'].astype('category')
df['data_cat'] = df['data_cat'].astype('category')

df[['rq_cat', 'data_cat']].head(5)
# Out:
#                                               rq_cat  \
# 0  Intergenerational Wealth Mobility and Inheritance
# 1               Empirical Estimates and Determinants
# 2               Empirical Estimates and Determinants
# 3            Measurement and Methodological Advances
# 4               Empirical Estimates and Determinants
#
#                      data_cat
# 0  Linked Administrative Data
# 1                  No dataset
# 2                  No dataset
# 3  Panel/Longitudinal Surveys
# 4                      Others

# %%
df['type'] = df['type'].replace({None: 'Not_specified'})

# %%
df[['year', 'rq_cat', 'data_cat', 'type', 'category_1', 'category_2']].isna().sum()
# Out:
# year            0
# rq_cat          0
# data_cat        0
# type            0
# category_1      0
# category_2    371
# dtype: int64

# %%
# df.to_csv(f'{path}/data_abstracts/true_mobility_studies_617_forKGs_cleaned.csv', index=False)

# %% [markdown]
# ## Create the graph (Abstract-based properties)
# ⚠️ Neo4j forces a direction flag, but you’re free to treat edges as undirected by querying with -[]- or projecting undirected copies for analytics. Keep attributes in a star around each :Paper; derive feature-to-feature links later. This keeps the graph lean, the semantics clear, and makes downstream analysis with GDS much simpler.

# %%
df = pd.read_csv(f'{path}/data_abstracts/true_mobility_studies_617_forKGs_cleaned.csv')

# %%
df[['id','cited_by']].head()
# Out:
#                                  id  \
# 0  https://openalex.org/W2564827629
# 1  https://openalex.org/W2117407660
# 2  https://openalex.org/W1515121029
# 3  https://openalex.org/W1966505070
# 4  https://openalex.org/W3041900243
#
#                                             cited_by
# 0  https://openalex.org/W2763922368, https://open...
# 1  https://openalex.org/W1966248378, https://open...
# 2  https://openalex.org/W1984539215, https://open...
# 3  https://openalex.org/W1577807578, https://open...
# 4  https://openalex.org/W4386370708, https://open...

# %%
df_citations = df.dropna(subset=['cited_by'])
df_citations = df_citations[['id', 'cited_by']]
df_citations['cited_by'] = df_citations['cited_by'].apply(lambda x: [s.strip() for s in x.split(',')])
df_citations = df_citations.explode('cited_by')
df_citations = df_citations.rename(columns={'cited_by': 'source_id', "id": "target_id"})

valid_ids = set(df['id'])
df_citations = df_citations[df_citations['source_id'].isin(valid_ids)]

print(f'\nNumber of citations: {len(df_citations)}')
df_citations.head(10)
# Out:
# Number of citations: 2596
#                           target_id                         source_id
# 0  https://openalex.org/W2564827629  https://openalex.org/W3123816425
# 0  https://openalex.org/W2564827629  https://openalex.org/W4289222991
# 0  https://openalex.org/W2564827629  https://openalex.org/W4386370708
# 0  https://openalex.org/W2564827629  https://openalex.org/W3163153651
# 0  https://openalex.org/W2564827629  https://openalex.org/W4393244952
# 0  https://openalex.org/W2564827629  https://openalex.org/W4407152405
# 0  https://openalex.org/W2564827629  https://openalex.org/W2947666646
# 0  https://openalex.org/W2564827629  https://openalex.org/W3022704615
# 0  https://openalex.org/W2564827629  https://openalex.org/W4280580662
# 0  https://openalex.org/W2564827629  https://openalex.org/W4283657131

# %%
import pandas as pd
from neo4j import GraphDatabase

# Connect to Neo4j
driver = GraphDatabase.driver("bolt://localhost:7690", auth=("neo4j", "your_password"))
df['category_1'] = df['category_1'].replace({'Others': 'Others_Measure'})
df['category_2'] = df['category_2'].replace({'Others': 'Others_Measure'})
df['data_cat'] = df['data_cat'].replace({'Others': 'Others_DataType'})
df['rq_cat'] = df['rq_cat'].replace({'Others': 'Others_RqType'})


with driver.session() as session:
    session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (y:Year) REQUIRE y.name IS UNIQUE")
    session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (m:Measure) REQUIRE m.name IS UNIQUE")
    session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (ds:DataType) REQUIRE ds.name IS UNIQUE")
    session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (r:RqType) REQUIRE r.name IS UNIQUE")
    session.run("CREATE CONSTRAINT IF NOT EXISTS FOR (tp:Type) REQUIRE tp.name IS UNIQUE")

def safe_str(val):
    """Return string if not null/NaN, else None."""
    if pd.isna(val) or str(val).strip().lower() in {"", "nan", "none"}:
        return None
    return str(val).strip()

def create_graph(tx, row):
    # Sanitize all inputs
    article_id = safe_str(row.get("id"))
    year = int(row["year"]) if not pd.isna(row["year"]) else None
    measure1 = safe_str(row.get("category_1"))
    measure2 = safe_str(row.get("category_2"))
    datatype = safe_str(row.get("data_cat"))
    rqtype = safe_str(row.get("rq_cat"))
    type = safe_str(row.get("type"))

    # Skip the row if any required values are None
    if not all([article_id, year, datatype, rqtype, type]):
        print(f"[SKIP] Missing required data in row: {row.get('id')}")
        return  # skip this row

    # Skip measure1 or measure2 if they're None, and adjust the Cypher
    query = """
    MERGE (p:Paper {id: $article_id})
    MERGE (y:Year {name: $year})
    MERGE (m1:Measure {name: $measure1})
    MERGE (ds:DataType {name: $datatype})
    MERGE (rq:RqType {name: $rqtype}) 
    MERGE (tp:Type {name: $type})

    // Supernodes 
    MERGE (p)-[:HAS_YEAR]->(y)
    MERGE (p)-[:HAS_TYPE]->(tp)
    MERGE (p)-[:HAS_DATATYPE]->(ds)
    MERGE (p)-[:HAS_RQTYPE]->(rq)
    MERGE (p)-[:HAS_MEASURE]->(m1)

    // Properties
    MERGE (y)-[:PERFORMS {article_id: $article_id}]->(tp)
    MERGE (tp)-[:USES {article_id: $article_id}]->(m1)
    MERGE (m1)-[:APPLIED_WITH {article_id: $article_id}]->(ds)
    MERGE (ds)-[:TO_ANSWER {article_id: $article_id}]->(rq)
    MERGE (rq)-[:IS_ANSWERED_IN {article_id: $article_id}]->(y)
    """
    
    if measure2:
        query += "\nMERGE (m2:Measure {name: $measure2})\nMERGE (p)-[:HAS_MEASURE]->(m2)\nMERGE (tp)-[:USES {article_id: $article_id}]->(m2)\nMERGE (m2)-[:APPLIED_WITH {article_id: $article_id}]->(ds)"

    tx.run(query, {
        "year": year,
        "measure1": measure1,
        "measure2": measure2,
        "datatype": datatype,
        "rqtype": rqtype,
        "type": type,
        "article_id": article_id,
    })
    

# Loop through DataFrame and create graph
with driver.session() as session:
    for _, row in df.iterrows():
        session.execute_write(create_graph, row)



# Create the citation relationships
with driver.session() as session:
    query = """
    UNWIND $rows AS row
    MATCH (a:Paper {id: row.source_id})
    MATCH (b:Paper {id: row.target_id})
    MERGE (a)-[:CITES]->(b)
    """
    session.run(query, parameters={"rows": df_citations.to_dict("records")})

driver.close()

# %% [markdown]
# # Graph Structure Analysis

# %% [markdown]
# * After adding the year nodes, it looks more concentrated.

# %%
df_edges = pd.read_csv(f"{path}/results/weights_properties_only_noTypeYear.csv")

fig = gr.plot_feature_graph_single(
        df_edges,
        title="Feature Citation Graph with Discrete Colours and Legend"
        )
fig.show()

# %% [markdown]
# ### Zoom into the center?

# %%
df = pd.read_csv(f'{path}/results/weights_properties_only_noTypeYear.csv')
zoom_in_values = ['Regression-based Measures','Rank‐based Measures', 'Transition Matrix / Probability Measures', 'Absolute Mobility Measures', 
                  'Others_Measure', 'Decomposition / Structural Approaches',
                  'Panel/Longitudinal Surveys', 'Administrative/Registry Data', 'National Survey Data', 'Linked Administrative Data',
                  'International Panel Data', 'Others_DataType']

df_zoom = df[df['from_val'].isin(zoom_in_values) & df['to_val'].isin(zoom_in_values)]
fig_zoom = gr.plot_feature_graph_single(df_zoom, title="Zoom-in on Core Properties")
fig_zoom.show()

# %% [markdown]
# Measures vs. Data types construction haha ^^;
# ⚠️ So actually, not considering the citation it not interesting at all because then the weights are just how many times certain nodes are mentioned, and the relationships between the nodes are just the "node types" relationships.

# %% [markdown]
# ### Citations considered to create weights

# %%
df_feature_edges = pd.read_csv(f'{path}/results/weights_properties_citations_noTypeYear.csv')
fig_citation = gr.plot_feature_graph_single(df_feature_edges, title="Feature Citations", color_labels=gr.color_labels)
fig_citation.show()

# %%
# fig.write_image(f'{path}/results/Paper/img/feature_citation_graph.pdf')

# %% [markdown]
# # By setting a radius around the centroid (0,0)

# %%
df_feature_edges = pd.read_csv(f'{path}/results/weights_properties_citations_noTypeYear.csv')
fig_geom, fig_betw, fig_deg = gr.plot_centrality_subgraphs_single(df_feature_edges, gr.color_labels)
fig_geom.show()
fig_betw.show()
fig_deg.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 df_feature_edges = pd.read_csv(f'{path}/results/weights_properties_citations_noTypeYear_f1<>f2.csv')
#       2 fig_geom, fig_betw, fig_deg = gr.plot_centrality_subgraphs_single(df_feature_edges, gr.color_labels)
#       3 fig_geom.show()
#
# File /opt/anaconda3/envs/meta_wealth/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/envs/meta_wealth/lib/python3.12/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/anaconda3/envs/meta_wealth/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/envs/meta_wealth/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/anaconda3/envs/meta_wealth/lib/python3.12/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/serenekim/Desktop/PhD/meta-wealth_mobility/results/weights_properties_citations_noTypeYear_f1<>f2.csv'

# %%
# fig_geom.write_image(f'{path}/results/Paper/img/feature_geom_center_graph.pdf')
# fig_betw.write_image(f'{path}/results/Paper/img/feature_top_betweenness_graph.pdf')
# fig_deg.write_image(f'{path}/results/Paper/img/feature_top_degree_graph.pdf')

# %% [markdown]
# # Check the papers with the centroid properties

# %%
data = pd.read_csv(f'{path}/data_abstracts/true_mobility_studies_617_forKGs_cleaned.csv')

# %%
data.columns
# Out:
# Index(['id', 'title', 'year', 'doi', 'landing_page', 'abstract_inverted_index',
#        'language', 'is_oa', 'oa_status', 'oa_link', 'abstract', 'abstract_sm',
#        'authors_sm', 'domain', 'sort_gpt_1', 'sort_gpt_2', 'sort_gpt4o_1',
#        'sort_gpt4o_2', 'cited_by', 'len_cited_by', 'ref_count',
#        'cited_by_count', 'Q1', 'Q1_1', 'Q2', 'Q2_1', 'Q2_2', 'Q3', 'Q4', 'abs',
#        'index', 'category_n1', 'measure', 'specified', 'relevant',
#        'category_n2', 'measure_1', 'measure_2', 'category_3', 'file', 'id.1',
#        'Question1', 'Question2', 'rq_cat', 'RQ', 'data_cat', 'data_type',
#        'type', 'category_1', 'category_2', 'author_raw_names',
#        'author_raw_affiliations', 'topic_display_names', 'topic_scores',
#        'field_display_names', 'subfield_display_names'],
#       dtype='object')

# %%
data['category_1'].unique()
# Out:
# array(['Absolute Mobility Measures', 'Regression‐based Measures',
#        'Transition Matrix / Probability Measures', 'Others',
#        'Rank‐based Measures', 'Decomposition / Structural Approaches',
#        'Multigenerational Measures', 'Non‐parametric Approaches'],
#       dtype=object)

# %%
print(data[(data['data_cat'] == "Panel/Longitudinal Surveys") & (data['rq_cat'] == "Empirical Estimates and Determinants") & (data['category_1'] == "Regression‐based Measures")].shape)
data[(data['data_cat'] == "Panel/Longitudinal Surveys") & (data['rq_cat'] == "Empirical Estimates and Determinants") & (data['category_1'] == "Regression‐based Measures")][['id', 'title', 'year', 'data_cat', 'rq_cat', 'category_1', 'category_2']]
# Out:
# (47, 56)
#                                    id  \
# 9    https://openalex.org/W2411230938
# 20   https://openalex.org/W2148814768
# 24   https://openalex.org/W2802089178
# 46   https://openalex.org/W4238028113
# 72   https://openalex.org/W4308132439
# 73   https://openalex.org/W1020822704
# 75   https://openalex.org/W1444704346
# 93   https://openalex.org/W1580804840
# 114  https://openalex.org/W1963513809
# 123  https://openalex.org/W1988669335
# 185  https://openalex.org/W2127281421
# 197  https://openalex.org/W2157585414
# 215  https://openalex.org/W2210747677
# 233  https://openalex.org/W2351358614
# 237  https://openalex.org/W2353931744
# 238  https://openalex.org/W2355555430
# 239  https://openalex.org/W2363649169
# 241  https://openalex.org/W2364722826
# 242  https://openalex.org/W2365705769
# 244  https://openalex.org/W2368218525
# 248  https://openalex.org/W2380359989
# 262  https://openalex.org/W2553521091
# 266  https://openalex.org/W2587329652
# 276  https://openalex.org/W2612875108
# 285  https://openalex.org/W2756659966
# 287  https://openalex.org/W2766173862
# 302  https://openalex.org/W2883024550
# 309  https://openalex.org/W2895165109
# 337  https://openalex.org/W2943421593
# 350  https://openalex.org/W2978816005
# 367  https://openalex.org/W3033501614
# 381  https://openalex.org/W3093752946
# 387  https://openalex.org/W3119775080
# 393  https://openalex.org/W3121545129
# 423  https://openalex.org/W3125643021
# 436  https://openalex.org/W3156722884
# 505  https://openalex.org/W4285263003
# 507  https://openalex.org/W4286458987
# 513  https://openalex.org/W4296277673
# 516  https://openalex.org/W4304172618
# 544  https://openalex.org/W4381512763
# 547  https://openalex.org/W4381736130
# 552  https://openalex.org/W4385260730
# 574  https://openalex.org/W4391619986
# 582  https://openalex.org/W4395466247
# 593  https://openalex.org/W4401871424
# 612   https://openalex.org/W623596649
#
#                                                  title  year  \
# 9                 Income Mobility in the United States  2016
# 20   Has the Intergenerational Transmission of Econ...  2005
# 24   Can cultural consumption increase future earni...  2018
# 46                                        Status Traps  2016
# 72   Socioeconomic Mobility of Return Migrants: Evi...  2022
# 73   Poor dad, poor child? An investigation of inte...  2015
# 75   Intergenerational Earnings Elasticity Revisite...  2015
# 93   Is a College Degree Still the Great Equalizer?...  2011
# 114  Patterns of Intergenerational Mobility in Inco...  1992
# 123  THE INTERGENERATIONAL CORRELATION BETWEEN CHIL...  1990
# 185  Intergenerational Earnings Mobility in Singapo...  2008
# 197   INTERGENERATIONAL INCOME MOBILITY IN URBAN CHINA  2012
# 215  One size doesn’t fit all: a quantile analysis ...  2017
# 233  Income Mobility,Intergenerational Transmission...  2014
# 237  PERSISTENCE: NONCOGNITIVE SKILLS, ABILITY AND ...  2007
# 238  A Comparative Study of the Intergenerational I...  2014
# 239  On China's Intergenerational Income Mobility a...  2014
# 241  Analysis on the Multilevel Statistical Models ...  2009
# 242  The study of Relationship between Opportunity ...  2010
# 244  Intergenerational Income Mobility in China's L...  2013
# 248  Analysis of Intergenerational Income Mobility ...  2015
# 262  Intergenerational Mobility and Assortative Mat...  2005
# 266  Family Background and Earnings Inequality amon...  2017
# 276  Social mobility matters, and government can af...  2013
# 285  Direct Measures of Intergenerational Income Mo...  2018
# 287  Intergenerational income mobility and inequali...  2017
# 302  Veteran Status, Income, and Intergenerational ...  2018
# 309  Intergenerational Mobility in the US: What We ...  2018
# 337  Equalization or Selection? Reassessing the “Me...  2019
# 350  Intra-generational and Intergenerational Socia...  2019
# 367  Great Equalizer or Great Selector? Reconsideri...  2020
# 381        Trends in Intergenerational Income Mobility  2009
# 387  Does Economic Inequality Constrain Intergenera...  2021
# 393  Does a good father now have to be rich? Interg...  2019
# 423  Direct Measures of Intergenerational Income Mo...  2017
# 436  Essays on Intergenerational Income Mobility in...  2019
# 505   Trade Openness and Intergenerational Income Flow  2022
# 507  The Effect of Trade Liberalization on Intergen...  2022
# 513  The effects of education upward mobility on in...  2022
# 516  Family-Size Effect on Intergenerational Income...  2022
# 544  Intergenerational mobility of relative poverty...  2023
# 547  Intergenerational income mobility: New evidenc...  2023
# 552  Assessing the Role of Education on Intergenera...  2023
# 574  The Impact of the Level and Timing of Parental...  2024
# 582  Childhood behavior problems and adverse econom...  2024
# 593  Intergenerational income mobility and returns ...  2024
# 612  Do Education and Sex Matter For Australia’s In...  2012
#
#                        data_cat                                rq_cat  \
# 9    Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 20   Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 24   Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 46   Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 72   Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 73   Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 75   Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 93   Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 114  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 123  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 185  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 197  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 215  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 233  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 237  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 238  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 239  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 241  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 242  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 244  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 248  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 262  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 266  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 276  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 285  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 287  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 302  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 309  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 337  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 350  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 367  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 381  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 387  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 393  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 423  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 436  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 505  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 507  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 513  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 516  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 544  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 547  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 552  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 574  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 582  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 593  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
# 612  Panel/Longitudinal Surveys  Empirical Estimates and Determinants
#
#                     category_1                                category_2
# 9    Regression‐based Measures                                       NaN
# 20   Regression‐based Measures                                       NaN
# 24   Regression‐based Measures                                       NaN
# 46   Regression‐based Measures                                       NaN
# 72   Regression‐based Measures                                       NaN
# 73   Regression‐based Measures                                       NaN
# 75   Regression‐based Measures                                       NaN
# 93   Regression‐based Measures                                       NaN
# 114  Regression‐based Measures                                       NaN
# 123  Regression‐based Measures                                       NaN
# 185  Regression‐based Measures                                       NaN
# 197  Regression‐based Measures                                       NaN
# 215  Regression‐based Measures                                       NaN
# 233  Regression‐based Measures                                       NaN
# 237  Regression‐based Measures                                       NaN
# 238  Regression‐based Measures                                       NaN
# 239  Regression‐based Measures                                       NaN
# 241  Regression‐based Measures                                       NaN
# 242  Regression‐based Measures                                       NaN
# 244  Regression‐based Measures                                       NaN
# 248  Regression‐based Measures                                       NaN
# 262  Regression‐based Measures                                       NaN
# 266  Regression‐based Measures                                       NaN
# 276  Regression‐based Measures                                       NaN
# 285  Regression‐based Measures                       Rank‐based Measures
# 287  Regression‐based Measures                                       NaN
# 302  Regression‐based Measures                 Regression‐based Measures
# 309  Regression‐based Measures                                       NaN
# 337  Regression‐based Measures                                       NaN
# 350  Regression‐based Measures                                       NaN
# 367  Regression‐based Measures                 Regression‐based Measures
# 381  Regression‐based Measures                 Regression‐based Measures
# 387  Regression‐based Measures                                       NaN
# 393  Regression‐based Measures                 Regression‐based Measures
# 423  Regression‐based Measures                       Rank‐based Measures
# 436  Regression‐based Measures                       Rank‐based Measures
# 505  Regression‐based Measures                                       NaN
# 507  Regression‐based Measures                                       NaN
# 513  Regression‐based Measures                                       NaN
# 516  Regression‐based Measures                                       NaN
# 544  Regression‐based Measures  Transition Matrix / Probability Measures
# 547  Regression‐based Measures                       Rank‐based Measures
# 552  Regression‐based Measures                                       NaN
# 574  Regression‐based Measures                                       NaN
# 582  Regression‐based Measures                                       NaN
# 593  Regression‐based Measures                                       NaN
# 612  Regression‐based Measures     Decomposition / Structural Approaches

# %%
print(data[(data['data_cat'] == "Panel/Longitudinal Surveys") & (data['rq_cat'] == "Intergenerational Wealth Mobility and Inheritance") & (data['category_1'] == "Regression‐based Measures")].shape)
print(data[(data['data_cat'] == "Panel/Longitudinal Surveys") & (data['rq_cat'] == "Intergenerational Wealth Mobility and Inheritance") & (data['category_2'] == "Regression‐based Measures")].shape)
# Out:
# (47, 56)
# (6, 56)

# %%
data['citation_rank'] = data['cited_by_count'].rank(method='first', ascending=False)
data['citation_rank']
# Out:
# 0        4.0
# 1       22.0
# 2       34.0
# 3      132.0
# 4      217.0
#        ...
# 612    614.0
# 613    120.0
# 614    615.0
# 615    616.0
# 616    617.0
# Name: citation_rank, Length: 617, dtype: float64

# %%
citations_617 = pd.read_csv(f'{path}/results/citations_count_617only.csv')
citations_617 = citations_617.rename(columns={'paper': 'id'})
citations_617 = citations_617.merge(data[['id', 'title', 'data_cat', 'rq_cat', 'category_1', 'category_2', 'citation_rank', 'cited_by_count']], on='id', how='left')
citations_617['citation_rank_617'] = citations_617['citations_count'].rank(method='first', ascending=False)
citations_617.head(10)
# Out:
#                                  id  citations_count  \
# 0  https://openalex.org/W2105584013              169
# 1  https://openalex.org/W2022256544              150
# 2  https://openalex.org/W2122216841              131
# 3  https://openalex.org/W2091916425              112
# 4  https://openalex.org/W3093752946               98
# 5  https://openalex.org/W2119587652               93
# 6  https://openalex.org/W2155246844               74
# 7  https://openalex.org/W2082418718               72
# 8  https://openalex.org/W3121694509               67
# 9  https://openalex.org/W2288802977               58
#
#                                                title  \
# 0  Where is the land of Opportunity? The Geograph...
# 1  An Equilibrium Theory of the Distribution of I...
# 2  Income Inequality, Equality of Opportunity, an...
# 3  Fortunate Sons: New Estimates of Intergenerati...
# 4        Trends in Intergenerational Income Mobility
# 5  Cross-Country Differences in Intergenerational...
# 6  Is the United States Still a Land of Opportuni...
# 7  Intergenerational Income Mobility Among Daughters
# 8  The Intergenerational Earnings and Income Mobi...
# 9  CROSS‐COUNTRY RANKINGS IN INTERGENERATIONAL MO...
#
#                        data_cat  \
# 0    Linked Administrative Data
# 1                    No dataset
# 2      International Panel Data
# 3  Administrative/Registry Data
# 4    Panel/Longitudinal Surveys
# 5                    No dataset
# 6    Linked Administrative Data
# 7    Panel/Longitudinal Surveys
# 8    Linked Administrative Data
# 9                    No dataset
#
#                                               rq_cat  \
# 0               Empirical Estimates and Determinants
# 1                  Theoretical and Structural Models
# 2               Empirical Estimates and Determinants
# 3               Empirical Estimates and Determinants
# 4               Empirical Estimates and Determinants
# 5               Empirical Estimates and Determinants
# 6               Empirical Estimates and Determinants
# 7  Intergenerational Wealth Mobility and Inheritance
# 8  Intergenerational Wealth Mobility and Inheritance
# 9               Empirical Estimates and Determinants
#
#                               category_1  \
# 0                    Rank‐based Measures
# 1  Decomposition / Structural Approaches
# 2              Regression‐based Measures
# 3              Regression‐based Measures
# 4              Regression‐based Measures
# 5              Regression‐based Measures
# 6                    Rank‐based Measures
# 7              Regression‐based Measures
# 8              Regression‐based Measures
# 9              Regression‐based Measures
#
#                                  category_2  citation_rank  cited_by_count  \
# 0  Transition Matrix / Probability Measures            1.0          2341.0
# 1     Decomposition / Structural Approaches            2.0          2152.0
# 2                                       NaN            3.0          1529.0
# 3                                       NaN            6.0           654.0
# 4                 Regression‐based Measures           12.0           445.0
# 5                                       NaN            5.0           660.0
# 6                       Rank‐based Measures            7.0           619.0
# 7                                       NaN           15.0           401.0
# 8                 Regression‐based Measures           17.0           299.0
# 9                                       NaN           13.0           423.0
#
#    citation_rank_617
# 0                1.0
# 1                2.0
# 2                3.0
# 3                4.0
# 4                5.0
# 5                6.0
# 6                7.0
# 7                8.0
# 8                9.0
# 9               10.0

# %%
# citations_617.to_csv(f'{path}/results/citations_count_617only_with_ranks.csv', index=False)

# %%
citations_617 = pd.read_csv(f'{path}/results/citations_count_617only_with_ranks.csv')
len(citations_617)
# Out:
# 276

# %%
# Using go.Heatmap for more visualization options (instead of go.Histogram2d) ------------------------
import plotly.graph_objects as go

# Create bin edges
variable = 'rq_cat'
citations_617['percentile_bin'] = pd.qcut(
    citations_617['citation_rank_617'],
    q=10,
    labels=[f"P{i*10}-{(i+1)*10}" for i in range(10)],
    duplicates='drop'
)
y_labels = citations_617[f'{variable}']

# Create crosstab
heatmap_data = pd.crosstab(y_labels, citations_617['percentile_bin'], normalize='columns')

fig = go.Figure(
    go.Heatmap(
        z=heatmap_data.values,
        x=heatmap_data.columns.astype(str),
        y=heatmap_data.index,
        colorscale='Viridis',
        showscale=True,
        zmin=0,
        # zmax=heatmap_data.values.max(),
        zmax = 0.8,
        hoverongaps=False,
        xgap=2,  # horizontal border space
        ygap=2,  # vertical border space
        colorbar=dict(title='Probability Density')
    )
)

fig.update_layout(
    title=f"Distribution of {variable} across Citation Percentiles",
    xaxis_title="Citation Rank Percentile",
    yaxis_title=f"{variable}",
    # yaxis=dict(showticklabels=False) 
)

fig.show()

# %% [markdown]
# ### Using Citations_between_617 as weights

# %%
import plotly.graph_objects as go
import pandas as pd

# Define the variables you want dropdown control for
variables = ['category_1', 'category_2', 'data_cat', 'rq_cat']

# Bin citation rank
citations_617['percentile_bin'] = pd.qcut(
    citations_617['citation_rank_617'],
    q=10,
    labels=[f"P{i*10}-{(i+1)*10}" for i in range(10)],
    duplicates='drop'
)

# Create color scale
custom_colorscale = [
    [0.0, 'lightgray'],
    [0.000001, 'rgb(68,1,84)'],
    [1.0, 'rgb(253,231,37)']
]

# Store all heatmap traces
traces = []
buttons = []

for i, variable in enumerate(variables):
    pivot_table = (
        citations_617
        .groupby([variable, 'percentile_bin'], observed=True)['citations_count']
        .sum()
        .unstack(fill_value=0)
    )
    pivot_table = pivot_table / pivot_table.values.sum()

    trace = go.Heatmap(
        z=pivot_table.values,
        x=pivot_table.columns.astype(str),
        y=pivot_table.index,
        colorscale=custom_colorscale,
        zmin=0.00001,
        zmax=0.05,  # or pivot_table.values.max() if you want adaptive range
        xgap=2,
        ygap=2,
        visible=(i == 0),  # Only first is visible initially
        colorbar=dict(title="Normalized Citations")
    )
    traces.append(trace)

    # Add dropdown button
    button = dict(
        label=variable,
        method='update',
        args=[
            {'visible': [j == i for j in range(len(variables))]},
            {'title': f'Total Citations by {variable} and Citation Rank Percentile',
             'yaxis': {'title': variable}}
        ]
    )
    buttons.append(button)

# Create the figure with all traces and the dropdown
fig = go.Figure(data=traces)

fig.update_layout(
    updatemenus=[
        dict(
            type='dropdown',
            showactive=True,
            buttons=buttons,
            x=1.05,
            xanchor='left',
            y=1.1,
            yanchor='top'
        )
    ],
    title=f"Total Citations by {variables[0]} and Citation Rank Percentile",
    xaxis_title="Citation Rank Percentile",
    yaxis_title=variables[0]
)

fig.show()

# %%
fig.write_image(f'{path}/results/Paper/img/heatmap_citation_rank_{variable}.pdf')

# %%
citations_617['combined'] = citations_617['data_cat'] + ',' + citations_617['rq_cat'] + ',' + citations_617['category_1']
citations_617['combined'] = citations_617['combined'].astype('category')

# %%
citations_617['combined'] = (
    citations_617['data_cat'].astype(str) + ',' +
    citations_617['rq_cat'].astype(str) + ',' +
    citations_617['category_1'].astype(str)
)

combo_counts = (
    citations_617
    .groupby(['percentile_bin', 'combined'], observed=True)
    .size()
    .reset_index(name='count')
)

bin_totals = (
    citations_617
    .groupby('percentile_bin', observed=True)
    .size()
    .reset_index(name='bin_total')
)

combo_counts = combo_counts.merge(bin_totals, on='percentile_bin')
combo_counts['probability'] = combo_counts['count'] / combo_counts['bin_total']

# Select top-N combinations per bin based on true probability
top_n = 5
top_combos = (
    combo_counts
    .sort_values(['percentile_bin', 'probability'], ascending=[True, False])
    .groupby('percentile_bin', observed=True)
    .head(top_n)
)

heatmap_data = pd.pivot_table(
    top_combos,
    values='probability',
    index='combined',
    columns='percentile_bin',
    fill_value=0,
    observed=True
)


fig = go.Figure(
    go.Heatmap(
        z=heatmap_data.values,
        x=heatmap_data.columns.astype(str),
        y=heatmap_data.index,
        colorscale='Viridis',
        showscale=True,
        zmin=0,
        # zmax=heatmap_data.values.max(),
        zmax=0.25,
        xgap=2,
        ygap=2,
        colorbar=dict(title='Probability')
    )
)

fig.update_layout(
    title=f"Top {top_n} Feature Combinations per Citation Percentile (True Probability)",
    xaxis_title="Citation Rank Percentile",
    yaxis_title="Feature Combination",
    # yaxis=dict(showticklabels=False)
)

fig.show()

# %%
combo_counts[(combo_counts['percentile_bin'] == 'P0-10') & (combo_counts['probability'] > 0)].sort_values('probability', ascending=False)
# Out:
#    percentile_bin                                           combined  count  \
# 17          P0-10  Panel/Longitudinal Surveys,Empirical Estimates...      5
# 12          P0-10  No dataset,Empirical Estimates and Determinant...      4
# 6           P0-10  Linked Administrative Data,Empirical Estimates...      2
# 11          P0-10  National Survey Data,Intergenerational Wealth ...      2
# 0           P0-10  Administrative/Registry Data,Empirical Estimat...      1
# 10          P0-10  Linked Administrative Data,Policy, Institution...      1
# 16          P0-10  Panel/Longitudinal Surveys,Demographic Differe...      1
# 15          P0-10  Others,Empirical Estimates and Determinants,Ot...      1
# 14          P0-10  No dataset,Theoretical and Structural Models,D...      1
# 13          P0-10  No dataset,Intergenerational Wealth Mobility a...      1
# 9           P0-10  Linked Administrative Data,Intergenerational W...      1
# 1           P0-10  Administrative/Registry Data,Intergenerational...      1
# 8           P0-10  Linked Administrative Data,Intergenerational W...      1
# 7           P0-10  Linked Administrative Data,Empirical Estimates...      1
# 5           P0-10  Linked Administrative Data,Demographic Differe...      1
# 4           P0-10  International Panel Data,Empirical Estimates a...      1
# 3           P0-10  Administrative/Registry Data,Policy, Instituti...      1
# 2           P0-10  Administrative/Registry Data,Measurement and M...      1
# 18          P0-10  Panel/Longitudinal Surveys,Intergenerational W...      1
#
#     bin_total  probability
# 17         28     0.178571
# 12         28     0.142857
# 6          28     0.071429
# 11         28     0.071429
# 0          28     0.035714
# 10         28     0.035714
# 16         28     0.035714
# 15         28     0.035714
# 14         28     0.035714
# 13         28     0.035714
# 9          28     0.035714
# 1          28     0.035714
# 8          28     0.035714
# 7          28     0.035714
# 5          28     0.035714
# 4          28     0.035714
# 3          28     0.035714
# 2          28     0.035714
# 18         28     0.035714

# %%
# fig.write_image(f'{path}/results/Paper/img/heatmap_top_combos_citation_rank.pdf')
